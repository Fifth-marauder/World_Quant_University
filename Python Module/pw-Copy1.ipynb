# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
def describe(key):

    total = sum([script[key] for script in scripts])
    avg = sum([script[key] for script in scripts])/len(scripts)
    s = (sum([(script[key]-avg)**2 for script in scripts])/len(scripts))**0.5
    ls=[script[key] for script in scripts]
    ls.sort()
    q25 = ls[int((len(scripts)+1)/4)]
    med = ls[int((len(scripts)+1)/2)]
    q75 = ls[int((len(scripts)+1)*3/4)]

    return (total, avg, s, q25, med, q75)

# %%
summary = [('items', describe('items')),
           ('quantity', describe('quantity')),
           ('nic', describe('nic')),
           ('act_cost', describe('act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = list(set([script['bnf_name'] for script in scripts]))
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    groups[script['bnf_name']].append(script)
    # INSERT ...`

# %%
groups['Imuvac_Vac 0.5ml Pfs']
# Out:
# [{'bnf_code': '1404000H0BNAAAF',
#   'items': 17,
#   'practice': 'N81016',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 112.03,
#   'act_cost': 103.71,
#   'quantity': 17},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 125,
#   'practice': 'N81047',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 823.75,
#   'act_cost': 762.58,
#   'quantity': 125},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 87,
#   'practice': 'N81053',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 573.33,
#   'act_cost': 530.75,
#   'quantity': 87},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 10,
#   'practice': 'N81090',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 65.9,
#   'act_cost': 61.01,
#   'quantity': 10},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 39,
#   'practice': 'N81024',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 257.01,
#   'act_cost': 237.92,
#   'quantity': 39},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 8,
#   'practice': 'N81040',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 52.72,
#   'act_cost': 48.8,
#   'quantity': 8},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 39,
#   'practice': 'N81023',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 257.01,
#   'act_cost': 237.93,
#   'quantity': 39},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 25,
#   'practice': 'N81091',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 164.75,
#   'act_cost': 152.53,
#   'quantity': 25},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 29,
#   'practice': 'N81093',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 191.11,
#   'act_cost': 176.92,
#   'quantity': 29},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 10,
#   'practice': 'A81012',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 65.9,
#   'act_cost': 61.01,
#   'quantity': 10},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 25,
#   'practice': 'A81033',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 164.75,
#   'act_cost': 152.52,
#   'quantity': 25},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 11,
#   'practice': 'P87003',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 72.49,
#   'act_cost': 67.11,
#   'quantity': 11},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 48,
#   'practice': 'P87020',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 316.32,
#   'act_cost': 292.83,
#   'quantity': 48},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 14,
#   'practice': 'P87659',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 92.26,
#   'act_cost': 85.41,
#   'quantity': 14},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 14,
#   'practice': 'P88009',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 92.26,
#   'act_cost': 85.41,
#   'quantity': 14},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 28,
#   'practice': 'P88019',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 184.52,
#   'act_cost': 170.82,
#   'quantity': 28},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 10,
#   'practice': 'P88624',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 65.9,
#   'act_cost': 61.01,
#   'quantity': 10},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 17,
#   'practice': 'P92006',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 112.03,
#   'act_cost': 103.71,
#   'quantity': 17},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 8,
#   'practice': 'P92031',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 52.72,
#   'act_cost': 48.81,
#   'quantity': 8},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 2,
#   'practice': 'B82016',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 13.18,
#   'act_cost': 12.2,
#   'quantity': 2},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 41,
#   'practice': 'B82027',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 270.19,
#   'act_cost': 250.1,
#   'quantity': 41},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 7,
#   'practice': 'M91034',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 46.13,
#   'act_cost': 42.71,
#   'quantity': 7},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 10,
#   'practice': 'M91604',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 65.9,
#   'act_cost': 61.01,
#   'quantity': 10},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 78,
#   'practice': 'M91612',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 514.02,
#   'act_cost': 475.86,
#   'quantity': 78},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 53,
#   'practice': 'M91647',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 349.27,
#   'act_cost': 323.34,
#   'quantity': 53},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 4,
#   'practice': 'M91650',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 26.36,
#   'act_cost': 24.4,
#   'quantity': 4},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 2,
#   'practice': 'M83708',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 13.18,
#   'act_cost': 12.2,
#   'quantity': 2},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 18,
#   'practice': 'M83713',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 118.62,
#   'act_cost': 109.81,
#   'quantity': 18},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 49,
#   'practice': 'H81034',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 322.91,
#   'act_cost': 298.94,
#   'quantity': 49},
#  {'bnf_code': '1404000H0BNAAAF',
#   'items': 31,
#   'practice': 'H81036',
#   'bnf_name': 'Imuvac_Vac 0.5ml Pfs',
#   'nic': 204.29,
#   'act_cost': 189.12,
#   'quantity': 31}]

# %%
# max_group = {name: [] for name in bnf_names}
# for i in groups:
#     max_group[i]= sum([member['items'] for member in i])

# %%
# max_group

# %%
name=max(max_group,key=max_group.get)
name_total=max_group[name]
print(name,name_total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-33f583e93d0e> in <module>()
# ----> 1 name=max(max_group,key=max_group.get)
#       2 name_total=max_group[name]
#       3 print(name,name_total)
#
# NameError: name 'max_group' is not defined

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
max_item = [max ([(sum([member['items'] for member in group]), name) for name, group in groups.items()]) [::-1]]
max_item
# Out:
# [('Omeprazole_Cap E/C 20mg', 113826)]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name')` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data, fields):
    names={tuple(item[field] for field in fields) for item in data}
    groups = {name :[] for name in names}
    for item in data:
        name = tuple(item[field] for field in fields)
        groups[name].append(item)
    return groups

# %%
result=group_by_field(scripts,('bnf_name','practice'))
result
# Out:
# {('Sharpsafe 4L',
#   'C82642'): [{'bnf_code': '21010900462',
#    'items': 3,
#    'practice': 'C82642',
#    'bnf_name': 'Sharpsafe 4L',
#    'nic': 7.35,
#    'act_cost': 6.84,
#    'quantity': 3}],
#  ('Sevredol_Tab 10mg',
#   'N82669'): [{'bnf_code': '0407020Q0BHACCD',
#    'items': 4,
#    'practice': 'N82669',
#    'bnf_name': 'Sevredol_Tab 10mg',
#    'nic': 7.96,
#    'act_cost': 7.82,
#    'quantity': 84}],
#  ('Salmeterol_Pdr For Inh 50mcg (60 D)',
#   'P83603'): [{'bnf_code': '0301011U0AAAEAE',
#    'items': 4,
#    'practice': 'P83603',
#    'bnf_name': 'Salmeterol_Pdr For Inh 50mcg (60 D)',
#    'nic': 175.55,
#    'act_cost': 162.58,
#    'quantity': 5}],
#  ('Solifenacin_Tab 5mg',
#   'M85652'): [{'bnf_code': '0704020ABAAAAAA',
#    'items': 8,
#    'practice': 'M85652',
#    'bnf_name': 'Solifenacin_Tab 5mg',
#    'nic': 197.92,
#    'act_cost': 183.82,
#    'quantity': 215}],
#  ('Rabeprazole Sod_Tab E/C 10mg',
#   'P81100'): [{'bnf_code': '0103050T0AAAAAA',
#    'items': 2,
#    'practice': 'P81100',
#    'bnf_name': 'Rabeprazole Sod_Tab E/C 10mg',
#    'nic': 4.02,
#    'act_cost': 3.73,
#    'quantity': 84}],
#  ('Chlorhex Glucon_Mthwsh 0.2%',
#   'A81029'): [{'bnf_code': '1203040E0AAABAB',
#    'items': 5,
#    'practice': 'A81029',
#    'bnf_name': 'Chlorhex Glucon_Mthwsh 0.2%',
#    'nic': 30.16,
#    'act_cost': 27.97,
#    'quantity': 2400}],
#  ('Exenatide_Inj 2mg Pdr + Dil PF Dev P/R',
#   'A81602'): [{'bnf_code': '0601023Y0AAADAD',
#    'items': 1,
#    'practice': 'A81602',
#    'bnf_name': 'Exenatide_Inj 2mg Pdr + Dil PF Dev P/R',
#    'nic': 73.36,
#    'act_cost': 67.94,
#    'quantity': 4}],
#  ('Bisoprolol Fumar_Tab 3.75mg',
#   'A84014'): [{'bnf_code': '0204000H0AAAKAK',
#    'items': 9,
#    'practice': 'A84014',
#    'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#    'nic': 11.44,
#    'act_cost': 10.73,
#    'quantity': 308}],
#  ('Disulfiram_Tab 200mg',
#   'P84051'): [{'bnf_code': '0410010B0AAAAAA',
#    'items': 1,
#    'practice': 'P84051',
#    'bnf_name': 'Disulfiram_Tab 200mg',
#    'nic': 51.37,
#    'act_cost': 47.67,
#    'quantity': 28}],
#  ('Propranolol HCl_Tab 10mg',
#   'A89031'): [{'bnf_code': '0204000R0AAAHAH',
#    'items': 3,
#    'practice': 'A89031',
#    'bnf_name': 'Propranolol HCl_Tab 10mg',
#    'nic': 8.54,
#    'act_cost': 8.05,
#    'quantity': 288}],
#  ('Hydrocort_Crm 1%',
#   'M91647'): [{'bnf_code': '1304000V0AAADAD',
#    'items': 10,
#    'practice': 'M91647',
#    'bnf_name': 'Hydrocort_Crm 1%',
#    'nic': 11.7,
#    'act_cost': 10.97,
#    'quantity': 195}],
#  ('Metformin HCl_Tab 1g M/R',
#   'E85004'): [{'bnf_code': '0601022B0AAAVAV',
#    'items': 7,
#    'practice': 'E85004',
#    'bnf_name': 'Metformin HCl_Tab 1g M/R',
#    'nic': 68.16,
#    'act_cost': 63.19,
#    'quantity': 448}],
#  ('Rivaroxaban_Tab 20mg',
#   'M88646'): [{'bnf_code': '0208020Y0AAACAC',
#    'items': 18,
#    'practice': 'M88646',
#    'bnf_name': 'Rivaroxaban_Tab 20mg',
#    'nic': 869.4,
#    'act_cost': 805.97,
#    'quantity': 483}],
#  ('Elleste Duet_Tab 1mg',
#   'Y03079'): [{'bnf_code': '0604011L0BPABAW',
#    'items': 2,
#    'practice': 'Y03079',
#    'bnf_name': 'Elleste Duet_Tab 1mg',
#    'nic': 12.27,
#    'act_cost': 11.51,
#    'quantity': 112}],
#  ('Gatalin XL_Cap 16mg',
#   'M91612'): [{'bnf_code': '0411000F0BFABAF',
#    'items': 1,
#    'practice': 'M91612',
#    'bnf_name': 'Gatalin XL_Cap 16mg',
#    'nic': 32.45,
#    'act_cost': 30.05,
#    'quantity': 28}],
#  ('Ketoconazole_Shampoo 2%',
#   'Y01003'): [{'bnf_code': '1309000I0AAAAAA',
#    'items': 1,
#    'practice': 'Y01003',
#    'bnf_name': 'Ketoconazole_Shampoo 2%',
#    'nic': 2.77,
#    'act_cost': 2.58,
#    'quantity': 120}],
#  ('Fluticasone Fur_Nsl Spy 27.5mcg (120D)',
#   'F81070'): [{'bnf_code': '1202010W0AAAAAA',
#    'items': 10,
#    'practice': 'F81070',
#    'bnf_name': 'Fluticasone Fur_Nsl Spy 27.5mcg (120D)',
#    'nic': 64.4,
#    'act_cost': 59.74,
#    'quantity': 10}],
#  ('Co-Codamol_Tab 8mg/500mg',
#   'Y03819'): [{'bnf_code': '0407010F0AAAAAA',
#    'items': 1,
#    'practice': 'Y03819',
#    'bnf_name': 'Co-Codamol_Tab 8mg/500mg',
#    'nic': 0.89,
#    'act_cost': 0.84,
#    'quantity': 30}],
#  ('Isosorbide Mononit_Tab 20mg',
#   'N81047'): [{'bnf_code': '0206010K0AAACAC',
#    'items': 1,
#    'practice': 'N81047',
#    'bnf_name': 'Isosorbide Mononit_Tab 20mg',
#    'nic': 3.41,
#    'act_cost': 3.17,
#    'quantity': 56}],
#  ('Carbamazepine_Tab 100mg',
#   'C84035'): [{'bnf_code': '0408010C0AAABAB',
#    'items': 1,
#    'practice': 'C84035',
#    'bnf_name': 'Carbamazepine_Tab 100mg',
#    'nic': 2.07,
#    'act_cost': 1.93,
#    'quantity': 84}],
#  ('Buprenorphine_Tab Subling 200mcg S/F',
#   'P92653'): [{'bnf_code': '0407020B0AAABAB',
#    'items': 4,
#    'practice': 'P92653',
#    'bnf_name': 'Buprenorphine_Tab Subling 200mcg S/F',
#    'nic': 26.61,
#    'act_cost': 24.88,
#    'quantity': 264}],
#  ('Omeprazole_Cap E/C 20mg',
#   'H81050'): [{'bnf_code': '0103050P0AAAAAA',
#    'items': 123,
#    'practice': 'H81050',
#    'bnf_name': 'Omeprazole_Cap E/C 20mg',
#    'nic': 205.22,
#    'act_cost': 191.81,
#    'quantity': 6314}],
#  ('Tramadol HCl_Cap 50mg',
#   'G82162'): [{'bnf_code': '040702040AAAAAA',
#    'items': 22,
#    'practice': 'G82162',
#    'bnf_name': 'Tramadol HCl_Cap 50mg',
#    'nic': 74.26,
#    'act_cost': 69.21,
#    'quantity': 2588}],
#  ('Warfarin Sod_Tab 3mg',
#   'G85012'): [{'bnf_code': '0208020V0AAABAB',
#    'items': 50,
#    'practice': 'G85012',
#    'bnf_name': 'Warfarin Sod_Tab 3mg',
#    'nic': 70.21,
#    'act_cost': 66.12,
#    'quantity': 2656}],
#  ('Lansoprazole_Cap 30mg (E/C Gran)',
#   'G85715'): [{'bnf_code': '0103050L0AAAAAA',
#    'items': 14,
#    'practice': 'G85715',
#    'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#    'nic': 23.04,
#    'act_cost': 21.7,
#    'quantity': 581}],
#  ('Synalar_Crm 0.025%',
#   'M83100'): [{'bnf_code': '1304000N0BBAAAB',
#    'items': 2,
#    'practice': 'M83100',
#    'bnf_name': 'Synalar_Crm 0.025%',
#    'nic': 8.28,
#    'act_cost': 7.69,
#    'quantity': 60}],
#  ('Tiotropium_Pdr For Inh Cap 18mcg + Dev',
#   'A89031'): [{'bnf_code': '0301020Q0AAAAAA',
#    'items': 1,
#    'practice': 'A89031',
#    'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg + Dev',
#    'nic': 34.87,
#    'act_cost': 32.29,
#    'quantity': 30}],
#  ('Anusol_Oint',
#   'N82646'): [{'bnf_code': '0107010Z0BCABAF',
#    'items': 2,
#    'practice': 'N82646',
#    'bnf_name': 'Anusol_Oint',
#    'nic': 4.9,
#    'act_cost': 4.56,
#    'quantity': 50}],
#  ('Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'N81085'): [{'bnf_code': '21300000402',
#    'items': 1,
#    'practice': 'N81085',
#    'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#    'nic': 5.35,
#    'act_cost': 4.97,
#    'quantity': 30}],
#  ('Calcipotriol_Oint 50mcg/1g',
#   'P92031'): [{'bnf_code': '1305020D0AAAAAA',
#    'items': 1,
#    'practice': 'P92031',
#    'bnf_name': 'Calcipotriol_Oint 50mcg/1g',
#    'nic': 23.12,
#    'act_cost': 21.42,
#    'quantity': 120}],
#  ('Mebeverine HCl_Tab 135mg',
#   'P83021'): [{'bnf_code': '0102000P0AAABAB',
#    'items': 34,
#    'practice': 'P83021',
#    'bnf_name': 'Mebeverine HCl_Tab 135mg',
#    'nic': 150.08,
#    'act_cost': 142.65,
#    'quantity': 2878}],
#  ('Ramipril_Tab 1.25mg',
#   'P81607'): [{'bnf_code': '0205051R0AAAKAK',
#    'items': 1,
#    'practice': 'P81607',
#    'bnf_name': 'Ramipril_Tab 1.25mg',
#    'nic': 1.65,
#    'act_cost': 1.54,
#    'quantity': 28}],
#  ('Salivix Pastil (App)',
#   'P92607'): [{'bnf_code': '21210000012',
#    'items': 2,
#    'practice': 'P92607',
#    'bnf_name': 'Salivix Pastil (App)',
#    'nic': 14.2,
#    'act_cost': 13.17,
#    'quantity': 200}],
#  ('Prochlpzine Mal_Tab 5mg',
#   'G81658'): [{'bnf_code': '0406000T0AAAGAG',
#    'items': 8,
#    'practice': 'G81658',
#    'bnf_name': 'Prochlpzine Mal_Tab 5mg',
#    'nic': 12.68,
#    'act_cost': 11.95,
#    'quantity': 366}],
#  ('Quinine Sulf_Tab 200mg',
#   'P88009'): [{'bnf_code': '0504010Y0AAAFAF',
#    'items': 5,
#    'practice': 'P88009',
#    'bnf_name': 'Quinine Sulf_Tab 200mg',
#    'nic': 8.05,
#    'act_cost': 7.51,
#    'quantity': 140}],
#  ('Acamprosate Calc_Tab E/C 333mg',
#   'P92621'): [{'bnf_code': '0410010A0AAAAAA',
#    'items': 4,
#    'practice': 'P92621',
#    'bnf_name': 'Acamprosate Calc_Tab E/C 333mg',
#    'nic': 67.22,
#    'act_cost': 62.58,
#    'quantity': 336}],
#  ('Propylthiouracil_Tab 50mg',
#   'C82071'): [{'bnf_code': '0602020N0AAABAB',
#    'items': 2,
#    'practice': 'C82071',
#    'bnf_name': 'Propylthiouracil_Tab 50mg',
#    'nic': 344.08,
#    'act_cost': 318.66,
#    'quantity': 324}],
#  ('Warfarin Sod_Tab 5mg',
#   'M85078'): [{'bnf_code': '0208020V0AAADAD',
#    'items': 1,
#    'practice': 'M85078',
#    'bnf_name': 'Warfarin Sod_Tab 5mg',
#    'nic': 5.57,
#    'act_cost': 5.27,
#    'quantity': 200}],
#  ('CosmoCol_Oral Pdr Sach (Plain)',
#   'Y00469'): [{'bnf_code': '0106040M0BGAFAA',
#    'items': 1,
#    'practice': 'Y00469',
#    'bnf_name': 'CosmoCol_Oral Pdr Sach (Plain)',
#    'nic': 3.95,
#    'act_cost': 3.67,
#    'quantity': 30}],
#  ('Omeprazole_Oral Susp 10mg/5ml',
#   'A89019'): [{'bnf_code': '0103050P0AABLBL',
#    'items': 1,
#    'practice': 'A89019',
#    'bnf_name': 'Omeprazole_Oral Susp 10mg/5ml',
#    'nic': 73.63,
#    'act_cost': 68.18,
#    'quantity': 150}],
#  ('Cosopt_Eye Dps 0.2ml Ud P/F',
#   'N81010'): [{'bnf_code': '1106000ABBBABAB',
#    'items': 1,
#    'practice': 'N81010',
#    'bnf_name': 'Cosopt_Eye Dps 0.2ml Ud P/F',
#    'nic': 28.59,
#    'act_cost': 26.48,
#    'quantity': 60}],
#  ('Quinine Sulf_Tab 300mg',
#   'N81093'): [{'bnf_code': '0504010Y0AAAHAH',
#    'items': 3,
#    'practice': 'N81093',
#    'bnf_name': 'Quinine Sulf_Tab 300mg',
#    'nic': 7.44,
#    'act_cost': 6.92,
#    'quantity': 112}],
#  ('Aciclovir_Tab 200mg',
#   'M85652'): [{'bnf_code': '0503021C0AAABAB',
#    'items': 1,
#    'practice': 'M85652',
#    'bnf_name': 'Aciclovir_Tab 200mg',
#    'nic': 1.36,
#    'act_cost': 1.27,
#    'quantity': 25}],
#  ('Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#   'Y00286'): [{'bnf_code': '1106000ABAAAAAA',
#    'items': 2,
#    'practice': 'Y00286',
#    'bnf_name': 'Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#    'nic': 5.43,
#    'act_cost': 5.05,
#    'quantity': 15}],
#  ('Tamsulosin HCl_Cap 400mcg M/R',
#   'P81125'): [{'bnf_code': '0704010U0AAAAAA',
#    'items': 68,
#    'practice': 'P81125',
#    'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#    'nic': 274.86,
#    'act_cost': 259.99,
#    'quantity': 2120}],
#  ('Tamsulosin/Dutasteride HCl_Cap 0.4/0.5mg',
#   'B81616'): [{'bnf_code': '0704010V0AAAAAA',
#    'items': 1,
#    'practice': 'B81616',
#    'bnf_name': 'Tamsulosin/Dutasteride HCl_Cap 0.4/0.5mg',
#    'nic': 23.76,
#    'act_cost': 22.01,
#    'quantity': 30}],
#  ('Felodipine_Tab 5mg M/R',
#   'F81046'): [{'bnf_code': '0206020F0AAABAB',
#    'items': 6,
#    'practice': 'F81046',
#    'bnf_name': 'Felodipine_Tab 5mg M/R',
#    'nic': 42.1,
#    'act_cost': 39.05,
#    'quantity': 280}],
#  ('Lisinopril_Tab 10mg',
#   'F81151'): [{'bnf_code': '0205051L0AAACAC',
#    'items': 20,
#    'practice': 'F81151',
#    'bnf_name': 'Lisinopril_Tab 10mg',
#    'nic': 19.75,
#    'act_cost': 18.55,
#    'quantity': 700}],
#  ('Isotard 60 XL_Tab 60mg',
#   'F81070'): [{'bnf_code': '0206010K0BWAAAE',
#    'items': 10,
#    'practice': 'F81070',
#    'bnf_name': 'Isotard 60 XL_Tab 60mg',
#    'nic': 122.39,
#    'act_cost': 113.64,
#    'quantity': 596}],
#  ('Fusidic Acid_Crm 2%',
#   'H85054'): [{'bnf_code': '1310012F0AAABAB',
#    'items': 6,
#    'practice': 'H85054',
#    'bnf_name': 'Fusidic Acid_Crm 2%',
#    'nic': 12.6,
#    'act_cost': 11.74,
#    'quantity': 105}],
#  ('Pravastatin Sod_Tab 20mg',
#   'A89012'): [{'bnf_code': '0212000X0AAABAB',
#    'items': 43,
#    'practice': 'A89012',
#    'bnf_name': 'Pravastatin Sod_Tab 20mg',
#    'nic': 31.98,
#    'act_cost': 32.44,
#    'quantity': 861}],
#  ('Aspirin_Tab 75mg',
#   'P88009'): [{'bnf_code': '0209000A0AAAJAJ',
#    'items': 17,
#    'practice': 'P88009',
#    'bnf_name': 'Aspirin_Tab 75mg',
#    'nic': 39.51,
#    'act_cost': 36.88,
#    'quantity': 979}],
#  ('Fultium-D3_Cap 800u',
#   'N83610'): [{'bnf_code': '0906040G0BXAAAN',
#    'items': 9,
#    'practice': 'N83610',
#    'bnf_name': 'Fultium-D3_Cap 800u',
#    'nic': 41.52,
#    'act_cost': 39.06,
#    'quantity': 346}],
#  ('Hydrocort/Clotrimazole_Crm 1%/1%',
#   'P86619'): [{'bnf_code': '1304000V0AACICI',
#    'items': 5,
#    'practice': 'P86619',
#    'bnf_name': 'Hydrocort/Clotrimazole_Crm 1%/1%',
#    'nic': 14.52,
#    'act_cost': 13.5,
#    'quantity': 180}],
#  ('Canagliflozin_Tab 100mg',
#   'P81215'): [{'bnf_code': '0601023AMAAAAAA',
#    'items': 1,
#    'practice': 'P81215',
#    'bnf_name': 'Canagliflozin_Tab 100mg',
#    'nic': 39.2,
#    'act_cost': 36.3,
#    'quantity': 30}],
#  ('Liq Paraf Light_Bath Add 63.4%',
#   'P88019'): [{'bnf_code': '1302011L0AAAIAI',
#    'items': 1,
#    'practice': 'P88019',
#    'bnf_name': 'Liq Paraf Light_Bath Add 63.4%',
#    'nic': 4.57,
#    'act_cost': 4.24,
#    'quantity': 500}],
#  ('Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#   'A89031'): [{'bnf_code': '0206010F0AACICI',
#    'items': 10,
#    'practice': 'A89031',
#    'bnf_name': 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#    'nic': 17.9,
#    'act_cost': 16.7,
#    'quantity': 10}],
#  ('Levetiracetam_Tab 250mg',
#   'A89003'): [{'bnf_code': '0408010A0AAAAAA',
#    'items': 10,
#    'practice': 'A89003',
#    'bnf_name': 'Levetiracetam_Tab 250mg',
#    'nic': 4.6,
#    'act_cost': 5.38,
#    'quantity': 140}],
#  ('Oseltamivir Phos_Cap 75mg',
#   'N81047'): [{'bnf_code': '0503040B0AAAAAA',
#    'items': 1,
#    'practice': 'N81047',
#    'bnf_name': 'Oseltamivir Phos_Cap 75mg',
#    'nic': 15.41,
#    'act_cost': 14.28,
#    'quantity': 10}],
#  ('Furosemide_Tab 40mg',
#   'P83005'): [{'bnf_code': '0202020L0AABDBD',
#    'items': 30,
#    'practice': 'P83005',
#    'bnf_name': 'Furosemide_Tab 40mg',
#    'nic': 29.06,
#    'act_cost': 27.58,
#    'quantity': 1179}],
#  ('Aspirin Disper_Tab 75mg',
#   'N83637'): [{'bnf_code': '0209000A0AAABAB',
#    'items': 129,
#    'practice': 'N83637',
#    'bnf_name': 'Aspirin Disper_Tab 75mg',
#    'nic': 90.02,
#    'act_cost': 85.55,
#    'quantity': 3600}],
#  ('Gabapentin_Cap 400mg',
#   'M91013'): [{'bnf_code': '0408010G0AAACAC',
#    'items': 5,
#    'practice': 'M91013',
#    'bnf_name': 'Gabapentin_Cap 400mg',
#    'nic': 23.32,
#    'act_cost': 21.95,
#    'quantity': 720}],
#  ('Flixonase_Aq Nsl Spy 50mcg (150 D)',
#   'P85601'): [{'bnf_code': '1202010M0BBACAC',
#    'items': 1,
#    'practice': 'P85601',
#    'bnf_name': 'Flixonase_Aq Nsl Spy 50mcg (150 D)',
#    'nic': 11.01,
#    'act_cost': 10.2,
#    'quantity': 1}],
#  ('Coloplast_SenSura Maxi Closed Bag Split',
#   'M91650'): [{'bnf_code': '23351003821',
#    'items': 1,
#    'practice': 'M91650',
#    'bnf_name': 'Coloplast_SenSura Maxi Closed Bag Split',
#    'nic': 88.75,
#    'act_cost': 82.16,
#    'quantity': 30}],
#  ('Azelastine HCl_Aq Eye Dps 0.05%',
#   'P86002'): [{'bnf_code': '1104020W0AAAAAA',
#    'items': 1,
#    'practice': 'P86002',
#    'bnf_name': 'Azelastine HCl_Aq Eye Dps 0.05%',
#    'nic': 6.4,
#    'act_cost': 5.94,
#    'quantity': 8}],
#  ('Gliclazide_Tab 40mg',
#   'N82065'): [{'bnf_code': '0601021M0AAARAR',
#    'items': 13,
#    'practice': 'N82065',
#    'bnf_name': 'Gliclazide_Tab 40mg',
#    'nic': 43.68,
#    'act_cost': 40.99,
#    'quantity': 364}],
#  ('Tamoxifen Cit_Tab 20mg',
#   'M91025'): [{'bnf_code': '0803041S0AAABAB',
#    'items': 2,
#    'practice': 'M91025',
#    'bnf_name': 'Tamoxifen Cit_Tab 20mg',
#    'nic': 5.57,
#    'act_cost': 5.28,
#    'quantity': 58}],
#  ('Vita-POS Paraf Eye Oint P/F',
#   'Y00151'): [{'bnf_code': '21300000710',
#    'items': 4,
#    'practice': 'Y00151',
#    'bnf_name': 'Vita-POS Paraf Eye Oint P/F',
#    'nic': 19.25,
#    'act_cost': 17.87,
#    'quantity': 35}],
#  ('Rewisca_Cap 75mg',
#   'M91604'): [{'bnf_code': '0408010AEBCADAC',
#    'items': 1,
#    'practice': 'M91604',
#    'bnf_name': 'Rewisca_Cap 75mg',
#    'nic': 90.8,
#    'act_cost': 84.07,
#    'quantity': 112}],
#  ('Co-Codamol_Tab 15mg/500mg',
#   'N81029'): [{'bnf_code': '0407010F0AAAKAK',
#    'items': 10,
#    'practice': 'N81029',
#    'bnf_name': 'Co-Codamol_Tab 15mg/500mg',
#    'nic': 90.24,
#    'act_cost': 83.86,
#    'quantity': 942}],
#  ('Lamictal_Tab Disper 25mg',
#   'N81085'): [{'bnf_code': '0408010H0BBAEAQ',
#    'items': 5,
#    'practice': 'N81085',
#    'bnf_name': 'Lamictal_Tab Disper 25mg',
#    'nic': 73.55,
#    'act_cost': 68.65,
#    'quantity': 175}],
#  ('Rochester_Clr Advantage Spirit Incont Sh',
#   'Y02344'): [{'bnf_code': '22303953121',
#    'items': 1,
#    'practice': 'Y02344',
#    'bnf_name': 'Rochester_Clr Advantage Spirit Incont Sh',
#    'nic': 51.05,
#    'act_cost': 47.27,
#    'quantity': 30}],
#  ('Dosulepin HCl_Tab 75mg',
#   'H85653'): [{'bnf_code': '0403010J0AAAIAI',
#    'items': 9,
#    'practice': 'H85653',
#    'bnf_name': 'Dosulepin HCl_Tab 75mg',
#    'nic': 7.66,
#    'act_cost': 8.01,
#    'quantity': 140}],
#  ('Alphosyl_Shampoo 2 In 1',
#   'Y03366'): [{'bnf_code': '1309000C0BGACAT',
#    'items': 1,
#    'practice': 'Y03366',
#    'bnf_name': 'Alphosyl_Shampoo 2 In 1',
#    'nic': 9.04,
#    'act_cost': 8.38,
#    'quantity': 500}],
#  ('Epaderm Crm',
#   'G82639'): [{'bnf_code': '21220000101',
#    'items': 5,
#    'practice': 'G82639',
#    'bnf_name': 'Epaderm Crm',
#    'nic': 34.75,
#    'act_cost': 32.23,
#    'quantity': 2500}],
#  ('Diazepam_Tab 2mg',
#   'N82065'): [{'bnf_code': '0401020K0AAAHAH',
#    'items': 31,
#    'practice': 'N82065',
#    'bnf_name': 'Diazepam_Tab 2mg',
#    'nic': 11.83,
#    'act_cost': 13.82,
#    'quantity': 453}],
#  ('Glucoject PLUS Lancets 0.20mm/33 Gauge',
#   'A81011'): [{'bnf_code': '21010900637',
#    'items': 11,
#    'practice': 'A81011',
#    'bnf_name': 'Glucoject PLUS Lancets 0.20mm/33 Gauge',
#    'nic': 44.62,
#    'act_cost': 41.62,
#    'quantity': 1400}],
#  ('Metronidazole_Tab 400mg',
#   'B81069'): [{'bnf_code': '0501110C0AAAJAJ',
#    'items': 9,
#    'practice': 'B81069',
#    'bnf_name': 'Metronidazole_Tab 400mg',
#    'nic': 39.24,
#    'act_cost': 37.05,
#    'quantity': 148}],
#  ('Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#   'D83021'): [{'bnf_code': '0206010F0AACICI',
#    'items': 4,
#    'practice': 'D83021',
#    'bnf_name': 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#    'nic': 7.16,
#    'act_cost': 6.68,
#    'quantity': 4}],
#  ('Chloramphen_Eye Dps 0.5%',
#   'A89019'): [{'bnf_code': '1103010C0AAAAAA',
#    'items': 15,
#    'practice': 'A89019',
#    'bnf_name': 'Chloramphen_Eye Dps 0.5%',
#    'nic': 24.32,
#    'act_cost': 22.71,
#    'quantity': 160}],
#  ('Aspirin Disper_Tab 75mg',
#   'M83075'): [{'bnf_code': '0209000A0AAABAB',
#    'items': 167,
#    'practice': 'M83075',
#    'bnf_name': 'Aspirin Disper_Tab 75mg',
#    'nic': 120.4,
#    'act_cost': 113.54,
#    'quantity': 4816}],
#  ('Beclomet Diprop_Inha 100mcg (200 D) CFF',
#   'G85095'): [{'bnf_code': '0302000C0AABFBF',
#    'items': 1,
#    'practice': 'G85095',
#    'bnf_name': 'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#    'nic': 14.84,
#    'act_cost': 13.75,
#    'quantity': 2}],
#  ('Otomize_Ear Spy 5ml',
#   'N84025'): [{'bnf_code': '120101050BCAAAB',
#    'items': 10,
#    'practice': 'N84025',
#    'bnf_name': 'Otomize_Ear Spy 5ml',
#    'nic': 39.24,
#    'act_cost': 36.46,
#    'quantity': 12}],
#  ('Octasa_MR Tab E/C 400mg',
#   'N81091'): [{'bnf_code': '0105010B0BIABAA',
#    'items': 1,
#    'practice': 'N81091',
#    'bnf_name': 'Octasa_MR Tab E/C 400mg',
#    'nic': 19.5,
#    'act_cost': 18.06,
#    'quantity': 90}],
#  ('Clement Clarke AirZone Stnd Range Peak F',
#   'P81159'): [{'bnf_code': '21120000132',
#    'items': 2,
#    'practice': 'P81159',
#    'bnf_name': 'Clement Clarke AirZone Stnd Range Peak F',
#    'nic': 9.38,
#    'act_cost': 8.71,
#    'quantity': 2}],
#  ('Pizotifen Malate_Tab 1.5mg',
#   'M91602'): [{'bnf_code': '0407042Q0AAACAC',
#    'items': 2,
#    'practice': 'M91602',
#    'bnf_name': 'Pizotifen Malate_Tab 1.5mg',
#    'nic': 4.02,
#    'act_cost': 3.75,
#    'quantity': 56}],
#  ('Hydromol Oint',
#   'Y02692'): [{'bnf_code': '21220000205',
#    'items': 3,
#    'practice': 'Y02692',
#    'bnf_name': 'Hydromol Oint',
#    'nic': 19.56,
#    'act_cost': 18.15,
#    'quantity': 2000}],
#  ('Quetiapine_Tab 300mg M/R',
#   'A81018'): [{'bnf_code': '0402010ABAAAXAX',
#    'items': 2,
#    'practice': 'A81018',
#    'bnf_name': 'Quetiapine_Tab 300mg M/R',
#    'nic': 255.0,
#    'act_cost': 236.19,
#    'quantity': 90}],
#  ('Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'P85615'): [{'bnf_code': '21070410110',
#    'items': 3,
#    'practice': 'P85615',
#    'bnf_name': 'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#    'nic': 45.12,
#    'act_cost': 41.81,
#    'quantity': 12}],
#  ('Quetiapine_Tab 150mg',
#   'Y02274'): [{'bnf_code': '0402010ABAAAFAF',
#    'items': 1,
#    'practice': 'Y02274',
#    'bnf_name': 'Quetiapine_Tab 150mg',
#    'nic': 1.02,
#    'act_cost': 1.06,
#    'quantity': 30}],
#  ('Erythromycin_Ethylsuc Susp 250mg/5ml S/F',
#   'Y00151'): [{'bnf_code': '0501050H0AAAMAM',
#    'items': 1,
#    'practice': 'Y00151',
#    'bnf_name': 'Erythromycin_Ethylsuc Susp 250mg/5ml S/F',
#    'nic': 10.64,
#    'act_cost': 9.86,
#    'quantity': 200}],
#  ('Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#   'H81034'): [{'bnf_code': '1202010M0AAACAC',
#    'items': 2,
#    'practice': 'H81034',
#    'bnf_name': 'Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#    'nic': 33.03,
#    'act_cost': 30.6,
#    'quantity': 3}],
#  ('Ins Humulin M3_100u/ml 10ml Vl',
#   'C83009'): [{'bnf_code': '0601012D0BBACAG',
#    'items': 3,
#    'practice': 'C83009',
#    'bnf_name': 'Ins Humulin M3_100u/ml 10ml Vl',
#    'nic': 78.4,
#    'act_cost': 72.61,
#    'quantity': 5}],
#  ('Montelukast_Tab Chble 5mg S/F',
#   'Y01011'): [{'bnf_code': '0303020G0AAAAAA',
#    'items': 2,
#    'practice': 'Y01011',
#    'bnf_name': 'Montelukast_Tab Chble 5mg S/F',
#    'nic': 4.5,
#    'act_cost': 4.19,
#    'quantity': 84}],
#  ('Ferr Glucon_Tab 300mg',
#   'P81079'): [{'bnf_code': '0901011H0AAAAAA',
#    'items': 2,
#    'practice': 'P81079',
#    'bnf_name': 'Ferr Glucon_Tab 300mg',
#    'nic': 7.8,
#    'act_cost': 7.24,
#    'quantity': 112}],
#  ('Colecal_Tab 800u',
#   'N83027'): [{'bnf_code': '0906040G0AACSCS',
#    'items': 1,
#    'practice': 'N83027',
#    'bnf_name': 'Colecal_Tab 800u',
#    'nic': 3.36,
#    'act_cost': 3.22,
#    'quantity': 28}],
#  ('Naseptin_Crm',
#   'P85613'): [{'bnf_code': '1202030S0BBAAAA',
#    'items': 1,
#    'practice': 'P85613',
#    'bnf_name': 'Naseptin_Crm',
#    'nic': 2.24,
#    'act_cost': 2.09,
#    'quantity': 15}],
#  ('Trandolapril_Cap 2mg',
#   'P81694'): [{'bnf_code': '0205051U0AAACAC',
#    'items': 1,
#    'practice': 'P81694',
#    'bnf_name': 'Trandolapril_Cap 2mg',
#    'nic': 7.44,
#    'act_cost': 6.9,
#    'quantity': 56}],
#  ('Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#   'N81093'): [{'bnf_code': '1106000ABAAAAAA',
#    'items': 1,
#    'practice': 'N81093',
#    'bnf_name': 'Dorzolamide/Timolol_Eye Dps 2%/0.5%',
#    'nic': 1.81,
#    'act_cost': 1.69,
#    'quantity': 5}],
#  ('Levothyrox Sod_Tab 25mcg',
#   'M88038'): [{'bnf_code': '0602010V0AABWBW',
#    'items': 184,
#    'practice': 'M88038',
#    'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#    'nic': 658.07,
#    'act_cost': 614.09,
#    'quantity': 6331}],
#  ('Coloplast_S5 Urine Drain Bag 2L',
#   'H81034'): [{'bnf_code': '22601006030',
#    'items': 1,
#    'practice': 'H81034',
#    'bnf_name': 'Coloplast_S5 Urine Drain Bag 2L',
#    'nic': 13.03,
#    'act_cost': 12.06,
#    'quantity': 10}],
#  ('Aripiprazole_Tab 10mg',
#   'P83020'): [{'bnf_code': '0402010ADAAAAAA',
#    'items': 1,
#    'practice': 'P83020',
#    'bnf_name': 'Aripiprazole_Tab 10mg',
#    'nic': 3.52,
#    'act_cost': 3.27,
#    'quantity': 56}],
#  ('Dressit Ster Dress Pack',
#   'N81127'): [{'bnf_code': '20030100167',
#    'items': 13,
#    'practice': 'N81127',
#    'bnf_name': 'Dressit Ster Dress Pack',
#    'nic': 114.0,
#    'act_cost': 105.55,
#    'quantity': 190}],
#  ('Orlistat_Cap 120mg',
#   'M85669'): [{'bnf_code': '0405010P0AAAAAA',
#    'items': 5,
#    'practice': 'M85669',
#    'bnf_name': 'Orlistat_Cap 120mg',
#    'nic': 87.75,
#    'act_cost': 81.3,
#    'quantity': 420}],
#  ('Sod Bicarb_Cap 500mg',
#   'M85715'): [{'bnf_code': '0902013S0AAACAC',
#    'items': 6,
#    'practice': 'M85715',
#    'bnf_name': 'Sod Bicarb_Cap 500mg',
#    'nic': 22.11,
#    'act_cost': 20.54,
#    'quantity': 616}],
#  ('Doxazosin Mesil_Tab 4mg',
#   'M83623'): [{'bnf_code': '0205040D0AAACAC',
#    'items': 23,
#    'practice': 'M83623',
#    'bnf_name': 'Doxazosin Mesil_Tab 4mg',
#    'nic': 56.28,
#    'act_cost': 52.4,
#    'quantity': 1876}],
#  ('Fluclox Sod_Oral Soln 125mg/5ml',
#   'H81034'): [{'bnf_code': '0501012G0AAAFAF',
#    'items': 1,
#    'practice': 'H81034',
#    'bnf_name': 'Fluclox Sod_Oral Soln 125mg/5ml',
#    'nic': 13.16,
#    'act_cost': 12.2,
#    'quantity': 200}],
#  ('Asacol_MR Tab E/C 800mg',
#   'H84030'): [{'bnf_code': '0105010B0BBAFAS',
#    'items': 2,
#    'practice': 'H84030',
#    'bnf_name': 'Asacol_MR Tab E/C 800mg',
#    'nic': 271.89,
#    'act_cost': 251.93,
#    'quantity': 416}],
#  ('Amoxicillin_Oral Susp 250mg/5ml',
#   'Y02620'): [{'bnf_code': '0501013B0AAAKAK',
#    'items': 11,
#    'practice': 'Y02620',
#    'bnf_name': 'Amoxicillin_Oral Susp 250mg/5ml',
#    'nic': 13.56,
#    'act_cost': 12.69,
#    'quantity': 1200}],
#  ('M.Sauer_URIbag 1.1L',
#   'A81018'): [{'bnf_code': '22902959000',
#    'items': 1,
#    'practice': 'A81018',
#    'bnf_name': 'M.Sauer_URIbag 1.1L',
#    'nic': 14.34,
#    'act_cost': 13.28,
#    'quantity': 1}],
#  ('Tegretol Prolonged Release_Tab 400mg M/R',
#   'L84042'): [{'bnf_code': '0408010C0BBAFAH',
#    'items': 4,
#    'practice': 'L84042',
#    'bnf_name': 'Tegretol Prolonged Release_Tab 400mg M/R',
#    'nic': 51.2,
#    'act_cost': 47.44,
#    'quantity': 280}],
#  ('Isosorbide Mononit_Tab 10mg',
#   'P81681'): [{'bnf_code': '0206010K0AAABAB',
#    'items': 17,
#    'practice': 'P81681',
#    'bnf_name': 'Isosorbide Mononit_Tab 10mg',
#    'nic': 36.55,
#    'act_cost': 35.05,
#    'quantity': 602}],
#  ('GlucoRx Lancets 0.31mm/30 Gauge',
#   'C82667'): [{'bnf_code': '21010900689',
#    'items': 4,
#    'practice': 'C82667',
#    'bnf_name': 'GlucoRx Lancets 0.31mm/30 Gauge',
#    'nic': 19.25,
#    'act_cost': 17.97,
#    'quantity': 700}],
#  ('Ibuprofen_Oral Susp 100mg/5ml S/F',
#   'N83622'): [{'bnf_code': '1001010J0AABHBH',
#    'items': 1,
#    'practice': 'N83622',
#    'bnf_name': 'Ibuprofen_Oral Susp 100mg/5ml S/F',
#    'nic': 1.25,
#    'act_cost': 1.17,
#    'quantity': 100}],
#  ('Celecoxib_Cap 200mg',
#   'L83008'): [{'bnf_code': '1001010AHAAABAB',
#    'items': 13,
#    'practice': 'L83008',
#    'bnf_name': 'Celecoxib_Cap 200mg',
#    'nic': 51.73,
#    'act_cost': 48.53,
#    'quantity': 958}],
#  ('Priadel_Tab 200mg',
#   'C87017'): [{'bnf_code': '0402030K0BFABAI',
#    'items': 6,
#    'practice': 'C87017',
#    'bnf_name': 'Priadel_Tab 200mg',
#    'nic': 7.34,
#    'act_cost': 7.47,
#    'quantity': 266}],
#  ('Salbutamol_Inha 100mcg (200 D) CFF',
#   'N83622'): [{'bnf_code': '0301011R0AAAPAP',
#    'items': 201,
#    'practice': 'N83622',
#    'bnf_name': 'Salbutamol_Inha 100mcg (200 D) CFF',
#    'nic': 409.5,
#    'act_cost': 381.6,
#    'quantity': 273}],
#  ('Tildiem LA 200_Cap 200mg',
#   'C82082'): [{'bnf_code': '0206020C0BBAEAX',
#    'items': 11,
#    'practice': 'C82082',
#    'bnf_name': 'Tildiem LA 200_Cap 200mg',
#    'nic': 69.19,
#    'act_cost': 64.19,
#    'quantity': 308}],
#  ('Naproxen_Tab E/C 500mg',
#   'Y04586'): [{'bnf_code': '1001010P0AAAIAI',
#    'items': 1,
#    'practice': 'Y04586',
#    'bnf_name': 'Naproxen_Tab E/C 500mg',
#    'nic': 3.51,
#    'act_cost': 3.36,
#    'quantity': 28}],
#  ('Clonidine HCl_Tab 25mcg',
#   'P81032'): [{'bnf_code': '0407042F0AAAAAA',
#    'items': 6,
#    'practice': 'P81032',
#    'bnf_name': 'Clonidine HCl_Tab 25mcg',
#    'nic': 40.64,
#    'act_cost': 37.91,
#    'quantity': 896}],
#  ('Mebendazole_Oral Susp 100mg/5ml',
#   'N83026'): [{'bnf_code': '0505010D0AAAAAA',
#    'items': 1,
#    'practice': 'N83026',
#    'bnf_name': 'Mebendazole_Oral Susp 100mg/5ml',
#    'nic': 1.55,
#    'act_cost': 1.45,
#    'quantity': 30}],
#  ('Hypromellose_Eye Dps 0.3%',
#   'H81615'): [{'bnf_code': '1108010F0AAAAAA',
#    'items': 6,
#    'practice': 'H81615',
#    'bnf_name': 'Hypromellose_Eye Dps 0.3%',
#    'nic': 9.94,
#    'act_cost': 9.28,
#    'quantity': 70}],
#  ('Fresubin Jucy_Drink (5 Flav)',
#   'P81215'): [{'bnf_code': '090402000BBTYA0',
#    'items': 2,
#    'practice': 'P81215',
#    'bnf_name': 'Fresubin Jucy_Drink (5 Flav)',
#    'nic': 156.0,
#    'act_cost': 144.44,
#    'quantity': 16000}],
#  ('Temgesic_Tab Subling 200mcg',
#   'P85007'): [{'bnf_code': '0407020B0BBAAAB',
#    'items': 2,
#    'practice': 'P85007',
#    'bnf_name': 'Temgesic_Tab Subling 200mcg',
#    'nic': 12.1,
#    'act_cost': 11.42,
#    'quantity': 120}],
#  ('Mefenamic Acid_Tab 500mg',
#   'B83661'): [{'bnf_code': '1001010N0AAADAD',
#    'items': 2,
#    'practice': 'B83661',
#    'bnf_name': 'Mefenamic Acid_Tab 500mg',
#    'nic': 24.6,
#    'act_cost': 22.8,
#    'quantity': 112}],
#  ('U100 Syrg Sle Use 0.5ml + 12mm Needle-St',
#   'C87622'): [{'bnf_code': '21010900410',
#    'items': 1,
#    'practice': 'C87622',
#    'bnf_name': 'U100 Syrg Sle Use 0.5ml + 12mm Needle-St',
#    'nic': 15.5,
#    'act_cost': 14.36,
#    'quantity': 100}],
#  ('Epilim Chrono 500_Tab 500mg C/R',
#   'J81046'): [{'bnf_code': '0408010W0BBALA2',
#    'items': 3,
#    'practice': 'J81046',
#    'bnf_name': 'Epilim Chrono 500_Tab 500mg C/R',
#    'nic': 48.9,
#    'act_cost': 45.6,
#    'quantity': 168}],
#  ('Isosorbide Mononit_Cap 25mg M/R',
#   'A89022'): [{'bnf_code': '0206010K0AAAHAH',
#    'items': 1,
#    'practice': 'A89022',
#    'bnf_name': 'Isosorbide Mononit_Cap 25mg M/R',
#    'nic': 3.4,
#    'act_cost': 3.16,
#    'quantity': 28}],
#  ('Co-Codamol_Cap 15mg/500mg',
#   'P83007'): [{'bnf_code': '0407010F0AAAVAV',
#    'items': 3,
#    'practice': 'P83007',
#    'bnf_name': 'Co-Codamol_Cap 15mg/500mg',
#    'nic': 21.75,
#    'act_cost': 20.17,
#    'quantity': 300}],
#  ('Migraleve_Pink Tab',
#   'P85003'): [{'bnf_code': '0407041A0BBABAG',
#    'items': 1,
#    'practice': 'P85003',
#    'bnf_name': 'Migraleve_Pink Tab',
#    'nic': 6.42,
#    'act_cost': 5.96,
#    'quantity': 24}],
#  ('Bard_Uriplan Collection Bag',
#   'P85015'): [{'bnf_code': '22600506003',
#    'items': 2,
#    'practice': 'P85015',
#    'bnf_name': 'Bard_Uriplan Collection Bag',
#    'nic': 15.25,
#    'act_cost': 14.25,
#    'quantity': 58}],
#  ('Ferr Glucon_Tab 300mg',
#   'P81025'): [{'bnf_code': '0901011H0AAAAAA',
#    'items': 3,
#    'practice': 'P81025',
#    'bnf_name': 'Ferr Glucon_Tab 300mg',
#    'nic': 4.88,
#    'act_cost': 4.66,
#    'quantity': 70}],
#  ('Buscopan_Tab 10mg',
#   'P82025'): [{'bnf_code': '0102000N0BBAAAB',
#    'items': 3,
#    'practice': 'P82025',
#    'bnf_name': 'Buscopan_Tab 10mg',
#    'nic': 18.0,
#    'act_cost': 16.7,
#    'quantity': 336}],
#  ('Methotrexate_Tab 2.5mg',
#   'F82670'): [{'bnf_code': '1001030U0AAABAB',
#    'items': 5,
#    'practice': 'F82670',
#    'bnf_name': 'Methotrexate_Tab 2.5mg',
#    'nic': 6.07,
#    'act_cost': 6.18,
#    'quantity': 96}],
#  ('Voltarol Emulgel_Aq Gel 1.16%',
#   'B81119'): [{'bnf_code': '1003020U0BBAAAA',
#    'items': 2,
#    'practice': 'B81119',
#    'bnf_name': 'Voltarol Emulgel_Aq Gel 1.16%',
#    'nic': 11.26,
#    'act_cost': 10.45,
#    'quantity': 200}],
#  ('Amiodarone HCl_Tab 200mg',
#   'Y00502'): [{'bnf_code': '0203020D0AAABAB',
#    'items': 2,
#    'practice': 'Y00502',
#    'bnf_name': 'Amiodarone HCl_Tab 200mg',
#    'nic': 0.4,
#    'act_cost': 0.6,
#    'quantity': 6}],
#  ('Beconase_Aq Nsl Spy 50mcg (200 D) 22g',
#   'M91013'): [{'bnf_code': '1202010C0BBABAA',
#    'items': 4,
#    'practice': 'M91013',
#    'bnf_name': 'Beconase_Aq Nsl Spy 50mcg (200 D) 22g',
#    'nic': 10.52,
#    'act_cost': 9.79,
#    'quantity': 4}],
#  ('Esomeprazole_Cap E/C 20mg',
#   'P81051'): [{'bnf_code': '0103050E0AAAFAF',
#    'items': 4,
#    'practice': 'P81051',
#    'bnf_name': 'Esomeprazole_Cap E/C 20mg',
#    'nic': 34.0,
#    'act_cost': 31.53,
#    'quantity': 280}],
#  ('Clotrimazole_Pess 500mg',
#   'M85070'): [{'bnf_code': '0702020F0AAAFAF',
#    'items': 1,
#    'practice': 'M85070',
#    'bnf_name': 'Clotrimazole_Pess 500mg',
#    'nic': 2.88,
#    'act_cost': 2.68,
#    'quantity': 1}],
#  ('Duocal_Super Solb Pdr',
#   'N81029'): [{'bnf_code': '090401000BBAPA0',
#    'items': 1,
#    'practice': 'N81029',
#    'bnf_name': 'Duocal_Super Solb Pdr',
#    'nic': 18.34,
#    'act_cost': 16.99,
#    'quantity': 400}],
#  ('Asacol_MR Tab E/C 400mg',
#   'P81002'): [{'bnf_code': '0105010B0BBAAAA',
#    'items': 7,
#    'practice': 'P81002',
#    'bnf_name': 'Asacol_MR Tab E/C 400mg',
#    'nic': 528.09,
#    'act_cost': 489.49,
#    'quantity': 1616}],
#  ('Sevredol_Tab 20mg',
#   'F81151'): [{'bnf_code': '0407020Q0BHADCE',
#    'items': 2,
#    'practice': 'F81151',
#    'bnf_name': 'Sevredol_Tab 20mg',
#    'nic': 21.22,
#    'act_cost': 19.67,
#    'quantity': 112}],
#  ('Mirtazapine_Orodisper Tab 45mg',
#   'F81147'): [{'bnf_code': '0403040X0AAAMAM',
#    'items': 7,
#    'practice': 'F81147',
#    'bnf_name': 'Mirtazapine_Orodisper Tab 45mg',
#    'nic': 7.76,
#    'act_cost': 7.97,
#    'quantity': 119}],
#  ('Epaderm Oint',
#   'P81712'): [{'bnf_code': '21220000100',
#    'items': 8,
#    'practice': 'P81712',
#    'bnf_name': 'Epaderm Oint',
#    'nic': 46.88,
#    'act_cost': 43.5,
#    'quantity': 3250}],
#  ('Fluticasone/Salmeterol_Inh 100/50mcg 60D',
#   'G85012'): [{'bnf_code': '0302000N0AAAXAX',
#    'items': 12,
#    'practice': 'G85012',
#    'bnf_name': 'Fluticasone/Salmeterol_Inh 100/50mcg 60D',
#    'nic': 432.0,
#    'act_cost': 400.08,
#    'quantity': 24}],
#  ('Lansoprazole_Orodisper Tab 30mg',
#   'A81031'): [{'bnf_code': '0103050L0AAAHAH',
#    'items': 4,
#    'practice': 'A81031',
#    'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#    'nic': 17.1,
#    'act_cost': 15.88,
#    'quantity': 140}],
#  ('Cetraben Crm 500g',
#   'Y01090'): [{'bnf_code': '21220000235',
#    'items': 7,
#    'practice': 'Y01090',
#    'bnf_name': 'Cetraben Crm 500g',
#    'nic': 41.93,
#    'act_cost': 38.9,
#    'quantity': 7}],
#  ('White Soft Paraf/Liq Paraf_(S) 50%/50%',
#   'C84136'): [{'bnf_code': '130201000AAA6A6',
#    'items': 1,
#    'practice': 'C84136',
#    'bnf_name': 'White Soft Paraf/Liq Paraf_(S) 50%/50%',
#    'nic': 4.57,
#    'act_cost': 4.24,
#    'quantity': 500}],
#  ('U100 Syrg Sle Use 1ml + 8mm Needle-Ster',
#   'Y02521'): [{'bnf_code': '21010900450',
#    'items': 2,
#    'practice': 'Y02521',
#    'bnf_name': 'U100 Syrg Sle Use 1ml + 8mm Needle-Ster',
#    'nic': 18.59,
#    'act_cost': 17.23,
#    'quantity': 130}],
#  ('Ventolin_Evohaler 100mcg (200 D)',
#   'Y04586'): [{'bnf_code': '0301011R0BEAIAP',
#    'items': 2,
#    'practice': 'Y04586',
#    'bnf_name': 'Ventolin_Evohaler 100mcg (200 D)',
#    'nic': 3.0,
#    'act_cost': 2.8,
#    'quantity': 2}],
#  ('Balsalazide Sod_Cap 750mg',
#   'N81062'): [{'bnf_code': '0105010D0AAABAB',
#    'items': 2,
#    'practice': 'N81062',
#    'bnf_name': 'Balsalazide Sod_Cap 750mg',
#    'nic': 114.66,
#    'act_cost': 106.28,
#    'quantity': 490}],
#  ('Bisoprolol Fumar_Tab 3.75mg',
#   'A81017'): [{'bnf_code': '0204000H0AAAKAK',
#    'items': 33,
#    'practice': 'A81017',
#    'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#    'nic': 31.58,
#    'act_cost': 30.25,
#    'quantity': 848}],
#  ('Hydroxocobalamin_Inj 1mg/ml 1ml Amp',
#   'E82613'): [{'bnf_code': '0901020N0AAABAB',
#    'items': 18,
#    'practice': 'E82613',
#    'bnf_name': 'Hydroxocobalamin_Inj 1mg/ml 1ml Amp',
#    'nic': 25.56,
#    'act_cost': 23.77,
#    'quantity': 18}],
#  ('Morph Sulf_Cap 10mg M/R',
#   'P81072'): [{'bnf_code': '0407020Q0AAEFEF',
#    'items': 1,
#    'practice': 'P81072',
#    'bnf_name': 'Morph Sulf_Cap 10mg M/R',
#    'nic': 5.21,
#    'act_cost': 4.94,
#    'quantity': 90}],
#  ('Tramadol HCl/Paracet_Tab 37.5mg/325mg',
#   'N81062'): [{'bnf_code': '040702040AAAUAU',
#    'items': 2,
#    'practice': 'N81062',
#    'bnf_name': 'Tramadol HCl/Paracet_Tab 37.5mg/325mg',
#    'nic': 49.17,
#    'act_cost': 45.64,
#    'quantity': 320}],
#  ('Nutrizym 22_Cap 340mg',
#   'P92006'): [{'bnf_code': '0109040N0BEACAZ',
#    'items': 2,
#    'practice': 'P92006',
#    'bnf_name': 'Nutrizym 22_Cap 340mg',
#    'nic': 359.96,
#    'act_cost': 333.46,
#    'quantity': 1080}],
#  ('Carbamazepine_Tab 400mg M/R',
#   'E84701'): [{'bnf_code': '0408010C0AAAHAH',
#    'items': 1,
#    'practice': 'E84701',
#    'bnf_name': 'Carbamazepine_Tab 400mg M/R',
#    'nic': 43.89,
#    'act_cost': 40.74,
#    'quantity': 240}],
#  ('Simvastatin_Tab 40mg',
#   'B83661'): [{'bnf_code': '0212000Y0AAADAD',
#    'items': 47,
#    'practice': 'B83661',
#    'bnf_name': 'Simvastatin_Tab 40mg',
#    'nic': 44.58,
#    'act_cost': 43.35,
#    'quantity': 1449}],
#  ('Flixotide_Evohaler 250mcg (120 D)',
#   'P92607'): [{'bnf_code': '0302000N0BBAZBC',
#    'items': 1,
#    'practice': 'P92607',
#    'bnf_name': 'Flixotide_Evohaler 250mcg (120 D)',
#    'nic': 36.14,
#    'act_cost': 33.47,
#    'quantity': 1}],
#  ('Pepti_Jnr Pdr',
#   'A89604'): [{'bnf_code': '090402000BBCDA0',
#    'items': 2,
#    'practice': 'A89604',
#    'bnf_name': 'Pepti_Jnr Pdr',
#    'nic': 130.6,
#    'act_cost': 120.93,
#    'quantity': 4500}],
#  ('Phenobarb_Tab 30mg',
#   'P81074'): [{'bnf_code': '0408010N0AAAJAJ',
#    'items': 5,
#    'practice': 'P81074',
#    'bnf_name': 'Phenobarb_Tab 30mg',
#    'nic': 7.8,
#    'act_cost': 7.28,
#    'quantity': 280}],
#  ('Citalopram Hydrob_Tab 40mg',
#   'K83013'): [{'bnf_code': '0403030D0AAACAC',
#    'items': 101,
#    'practice': 'K83013',
#    'bnf_name': 'Citalopram Hydrob_Tab 40mg',
#    'nic': 97.2,
#    'act_cost': 92.02,
#    'quantity': 2695}],
#  ('Quetiapine_Tab 300mg M/R',
#   'H85063'): [{'bnf_code': '0402010ABAAAXAX',
#    'items': 1,
#    'practice': 'H85063',
#    'bnf_name': 'Quetiapine_Tab 300mg M/R',
#    'nic': 170.0,
#    'act_cost': 157.39,
#    'quantity': 60}],
#  ('Coloplast_Simpla Profile Leg Bag 500ml 2',
#   'M86005'): [{'bnf_code': '22501005068',
#    'items': 1,
#    'practice': 'M86005',
#    'bnf_name': 'Coloplast_Simpla Profile Leg Bag 500ml 2',
#    'nic': 30.36,
#    'act_cost': 28.12,
#    'quantity': 10}],
#  ('Cilest_Tab',
#   'Y00620'): [{'bnf_code': '0703010G0BFAAAC',
#    'items': 1,
#    'practice': 'Y00620',
#    'bnf_name': 'Cilest_Tab',
#    'nic': 21.48,
#    'act_cost': 19.9,
#    'quantity': 189}],
#  ('Imipramine HCl_Tab 25mg',
#   'P81079'): [{'bnf_code': '0403010N0AAAEAE',
#    'items': 1,
#    'practice': 'P81079',
#    'bnf_name': 'Imipramine HCl_Tab 25mg',
#    'nic': 2.02,
#    'act_cost': 1.88,
#    'quantity': 56}],
#  ('Fultium-D3_Cap 20 000u',
#   'Y00446'): [{'bnf_code': '0906040G0BXACDR',
#    'items': 2,
#    'practice': 'Y00446',
#    'bnf_name': 'Fultium-D3_Cap 20 000u',
#    'nic': 29.0,
#    'act_cost': 27.07,
#    'quantity': 30}],
#  ('Co-Amoxiclav_Susp 125mg/31mg/5ml S/F',
#   'Y02483'): [{'bnf_code': '0501013K0AAADAD',
#    'items': 1,
#    'practice': 'Y02483',
#    'bnf_name': 'Co-Amoxiclav_Susp 125mg/31mg/5ml S/F',
#    'nic': 1.94,
#    'act_cost': 1.81,
#    'quantity': 100}],
#  ('Phenoxymethylpenicillin Pot_Tab 250mg',
#   'Y02344'): [{'bnf_code': '0501011P0AAAJAJ',
#    'items': 8,
#    'practice': 'Y02344',
#    'bnf_name': 'Phenoxymethylpenicillin Pot_Tab 250mg',
#    'nic': 14.26,
#    'act_cost': 13.4,
#    'quantity': 384}],
#  ('Nifedipine_Tab 20mg M/R',
#   'M85757'): [{'bnf_code': '0206020R0AAARAR',
#    'items': 2,
#    'practice': 'M85757',
#    'bnf_name': 'Nifedipine_Tab 20mg M/R',
#    'nic': 21.08,
#    'act_cost': 19.54,
#    'quantity': 112}],
#  ('Calc Carb_Tab Chble 1.5g (600mg) S/F',
#   'C85008'): [{'bnf_code': '0905011D0AAAKAK',
#    'items': 6,
#    'practice': 'C85008',
#    'bnf_name': 'Calc Carb_Tab Chble 1.5g (600mg) S/F',
#    'nic': 19.5,
#    'act_cost': 18.72,
#    'quantity': 224}],
#  ('Oxybutynin HCl_Tab 2.5mg',
#   'P81086'): [{'bnf_code': '0704020J0AAAAAA',
#    'items': 4,
#    'practice': 'P81086',
#    'bnf_name': 'Oxybutynin HCl_Tab 2.5mg',
#    'nic': 5.18,
#    'act_cost': 4.94,
#    'quantity': 252}],
#  ('Ranitidine HCl_Tab 300mg',
#   'M91647'): [{'bnf_code': '0103010T0AAACAC',
#    'items': 3,
#    'practice': 'M91647',
#    'bnf_name': 'Ranitidine HCl_Tab 300mg',
#    'nic': 7.28,
#    'act_cost': 6.98,
#    'quantity': 172}],
#  ('Levonorgest_Tab 1.5mg',
#   'C82047'): [{'bnf_code': '0703050A0AAABAB',
#    'items': 3,
#    'practice': 'C82047',
#    'bnf_name': 'Levonorgest_Tab 1.5mg',
#    'nic': 15.6,
#    'act_cost': 14.48,
#    'quantity': 3}],
#  ('Movelat_Gel',
#   'N81013'): [{'bnf_code': '1003020W0BBABAA',
#    'items': 1,
#    'practice': 'N81013',
#    'bnf_name': 'Movelat_Gel',
#    'nic': 7.19,
#    'act_cost': 6.67,
#    'quantity': 125}],
#  ('Difflam_Oral Rinse Soln 0.15%',
#   'L84033'): [{'bnf_code': '1203010E0BBAAAA',
#    'items': 2,
#    'practice': 'L84033',
#    'bnf_name': 'Difflam_Oral Rinse Soln 0.15%',
#    'nic': 32.5,
#    'act_cost': 30.11,
#    'quantity': 1500}],
#  ('Zomorph_Cap 30mg',
#   'Y02469'): [{'bnf_code': '0407020Q0BKABEG',
#    'items': 1,
#    'practice': 'Y02469',
#    'bnf_name': 'Zomorph_Cap 30mg',
#    'nic': 8.3,
#    'act_cost': 7.7,
#    'quantity': 60}],
#  ('K-Y Lubri Jelly',
#   'G82126'): [{'bnf_code': '21140000005',
#    'items': 2,
#    'practice': 'G82126',
#    'bnf_name': 'K-Y Lubri Jelly',
#    'nic': 4.66,
#    'act_cost': 4.34,
#    'quantity': 164}],
#  ('Salmeterol_Inha 25mcg (120 D) CFF',
#   'C84105'): [{'bnf_code': '0301011U0AAAHAH',
#    'items': 6,
#    'practice': 'C84105',
#    'bnf_name': 'Salmeterol_Inha 25mcg (120 D) CFF',
#    'nic': 175.56,
#    'act_cost': 162.6,
#    'quantity': 6}],
#  ('Movelat_Gel',
#   'P81072'): [{'bnf_code': '1003020W0BBABAA',
#    'items': 1,
#    'practice': 'P81072',
#    'bnf_name': 'Movelat_Gel',
#    'nic': 7.19,
#    'act_cost': 6.67,
#    'quantity': 125}],
#  ('Aspen_Sorbaderm No-Sting Barrier Film Sp',
#   'M83623'): [{'bnf_code': '23800298001',
#    'items': 1,
#    'practice': 'M83623',
#    'bnf_name': 'Aspen_Sorbaderm No-Sting Barrier Film Sp',
#    'nic': 5.99,
#    'act_cost': 5.56,
#    'quantity': 1}],
#  ('Qvar 100_Inha 100mcg (200 D)',
#   'N83026'): [{'bnf_code': '0302000C0BJABBF',
#    'items': 1,
#    'practice': 'N83026',
#    'bnf_name': 'Qvar 100_Inha 100mcg (200 D)',
#    'nic': 34.42,
#    'act_cost': 31.88,
#    'quantity': 2}],
#  ('Opus_SkinSafe Non Sting Prote Film',
#   'F81096'): [{'bnf_code': '23803368003',
#    'items': 1,
#    'practice': 'F81096',
#    'bnf_name': 'Opus_SkinSafe Non Sting Prote Film',
#    'nic': 73.52,
#    'act_cost': 68.06,
#    'quantity': 2}],
#  ('PF Drops 0.5% Carmellose Eye Dps 10ml',
#   'A89010'): [{'bnf_code': '21300000153',
#    'items': 2,
#    'practice': 'A89010',
#    'bnf_name': 'PF Drops 0.5% Carmellose Eye Dps 10ml',
#    'nic': 29.96,
#    'act_cost': 27.76,
#    'quantity': 4}],
#  ('Diclofenac Sod_Cap 75mg M/R',
#   'D83021'): [{'bnf_code': '1001010C0AAAWAW',
#    'items': 4,
#    'practice': 'D83021',
#    'bnf_name': 'Diclofenac Sod_Cap 75mg M/R',
#    'nic': 38.76,
#    'act_cost': 35.93,
#    'quantity': 224}],
#  ('Bisoprolol Fumar_Tab 2.5mg',
#   'Y02274'): [{'bnf_code': '0204000H0AAAJAJ',
#    'items': 29,
#    'practice': 'Y02274',
#    'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#    'nic': 26.52,
#    'act_cost': 24.91,
#    'quantity': 952}],
#  ('Perindopril Erbumine_Tab 4mg',
#   'N81127'): [{'bnf_code': '0205051M0AAABAB',
#    'items': 11,
#    'practice': 'N81127',
#    'bnf_name': 'Perindopril Erbumine_Tab 4mg',
#    'nic': 14.9,
#    'act_cost': 14.32,
#    'quantity': 410}],
#  ('Ganfort_Eye Dps 300mcg/5mg',
#   'P81133'): [{'bnf_code': '1106000AIBBAAAA',
#    'items': 4,
#    'practice': 'P81133',
#    'bnf_name': 'Ganfort_Eye Dps 300mcg/5mg',
#    'nic': 94.81,
#    'act_cost': 87.92,
#    'quantity': 21}],
#  ('Levonorgest_Tab 1.5mg',
#   'A89603'): [{'bnf_code': '0703050A0AAABAB',
#    'items': 2,
#    'practice': 'A89603',
#    'bnf_name': 'Levonorgest_Tab 1.5mg',
#    'nic': 10.4,
#    'act_cost': 9.65,
#    'quantity': 2}],
#  ('Ipratrop Brom_Inh Soln 500mcg/2ml Ud',
#   'M88038'): [{'bnf_code': '0301020I0AAACAC',
#    'items': 1,
#    'practice': 'M88038',
#    'bnf_name': 'Ipratrop Brom_Inh Soln 500mcg/2ml Ud',
#    'nic': 15.6,
#    'act_cost': 14.45,
#    'quantity': 120}],
#  ('Juvela_G/F W/F Fibre Flakes',
#   'N81088'): [{'bnf_code': '0904010ACBIABAC',
#    'items': 1,
#    'practice': 'N81088',
#    'bnf_name': 'Juvela_G/F W/F Fibre Flakes',
#    'nic': 2.78,
#    'act_cost': 2.59,
#    'quantity': 300}],
#  ('Calcipotriol_Scalp Soln 50mcg/ml',
#   'P81079'): [{'bnf_code': '1305020D0AAACAC',
#    'items': 3,
#    'practice': 'P81079',
#    'bnf_name': 'Calcipotriol_Scalp Soln 50mcg/ml',
#    'nic': 227.76,
#    'act_cost': 210.88,
#    'quantity': 240}],
#  ('Trimethoprim_Tab 200mg',
#   'C82667'): [{'bnf_code': '0501080W0AAAEAE',
#    'items': 37,
#    'practice': 'C82667',
#    'bnf_name': 'Trimethoprim_Tab 200mg',
#    'nic': 23.41,
#    'act_cost': 22.12,
#    'quantity': 286}],
#  ('Dexamfet Sulf_Tab 5mg',
#   'M83046'): [{'bnf_code': '0404000L0AAAJAJ',
#    'items': 1,
#    'practice': 'M83046',
#    'bnf_name': 'Dexamfet Sulf_Tab 5mg',
#    'nic': 99.0,
#    'act_cost': 91.66,
#    'quantity': 112}],
#  ('Keppra_Tab 1g',
#   'L84026'): [{'bnf_code': '0408010A0BBACAC',
#    'items': 3,
#    'practice': 'L84026',
#    'bnf_name': 'Keppra_Tab 1g',
#    'nic': 381.36,
#    'act_cost': 353.08,
#    'quantity': 240}],
#  ('Able Spacer',
#   'N81066'): [{'bnf_code': '21010230120',
#    'items': 1,
#    'practice': 'N81066',
#    'bnf_name': 'Able Spacer',
#    'nic': 4.39,
#    'act_cost': 4.08,
#    'quantity': 1}],
#  ('Pizotifen Malate_Tab 500mcg',
#   'P88625'): [{'bnf_code': '0407042Q0AAABAB',
#    'items': 3,
#    'practice': 'P88625',
#    'bnf_name': 'Pizotifen Malate_Tab 500mcg',
#    'nic': 6.09,
#    'act_cost': 5.67,
#    'quantity': 84}],
#  ('Nortriptyline_Tab 25mg',
#   'P81091'): [{'bnf_code': '0403010V0AAAEAE',
#    'items': 2,
#    'practice': 'P81091',
#    'bnf_name': 'Nortriptyline_Tab 25mg',
#    'nic': 71.05,
#    'act_cost': 66.0,
#    'quantity': 224}],
#  ('Seretide 50_Evohaler 50mcg/25mcg (120 D)',
#   'Y05438'): [{'bnf_code': '0302000N0BCADBE',
#    'items': 4,
#    'practice': 'Y05438',
#    'bnf_name': 'Seretide 50_Evohaler 50mcg/25mcg (120 D)',
#    'nic': 126.0,
#    'act_cost': 116.7,
#    'quantity': 7}],
#  ('Quinine Sulf_Tab 300mg',
#   'G82162'): [{'bnf_code': '0504010Y0AAAHAH',
#    'items': 16,
#    'practice': 'G82162',
#    'bnf_name': 'Quinine Sulf_Tab 300mg',
#    'nic': 24.2,
#    'act_cost': 23.0,
#    'quantity': 364}],
#  ('Hypromellose_Eye Dps 0.3%',
#   'K83051'): [{'bnf_code': '1108010F0AAAAAA',
#    'items': 55,
#    'practice': 'K83051',
#    'bnf_name': 'Hypromellose_Eye Dps 0.3%',
#    'nic': 86.62,
#    'act_cost': 80.86,
#    'quantity': 610}],
#  ('Colofac MR_Cap 200mg',
#   'A89019'): [{'bnf_code': '0102000P0BCAEAD',
#    'items': 9,
#    'practice': 'A89019',
#    'bnf_name': 'Colofac MR_Cap 200mg',
#    'nic': 47.04,
#    'act_cost': 44.25,
#    'quantity': 408}],
#  ('Ramipril_Cap 5mg',
#   'C84117'): [{'bnf_code': '0205051R0AAACAC',
#    'items': 21,
#    'practice': 'C84117',
#    'bnf_name': 'Ramipril_Cap 5mg',
#    'nic': 45.24,
#    'act_cost': 42.15,
#    'quantity': 1092}],
#  ('Loestrin 20_Tab',
#   'A89007'): [{'bnf_code': '0703010E0BBAAAA',
#    'items': 1,
#    'practice': 'A89007',
#    'bnf_name': 'Loestrin 20_Tab',
#    'nic': 2.3,
#    'act_cost': 2.14,
#    'quantity': 63}],
#  ('Oilatum_Crm',
#   'A81033'): [{'bnf_code': '130201000BBJPCD',
#    'items': 5,
#    'practice': 'A81033',
#    'bnf_name': 'Oilatum_Crm',
#    'nic': 25.04,
#    'act_cost': 23.24,
#    'quantity': 1100}],
#  ('Paroxetine HCl_Tab 20mg',
#   'F85676'): [{'bnf_code': '0403030P0AAAAAA',
#    'items': 4,
#    'practice': 'F85676',
#    'bnf_name': 'Paroxetine HCl_Tab 20mg',
#    'nic': 13.12,
#    'act_cost': 12.59,
#    'quantity': 252}],
#  ('Atenolol_Tab 25mg',
#   'N81023'): [{'bnf_code': '0204000E0AAAGAG',
#    'items': 8,
#    'practice': 'N81023',
#    'bnf_name': 'Atenolol_Tab 25mg',
#    'nic': 7.82,
#    'act_cost': 7.54,
#    'quantity': 308}],
#  ('Tiopex_Gel Eye Dps 1mg/g 0.4g Ud',
#   'N81013'): [{'bnf_code': '1106000Z0BHAAAS',
#    'items': 2,
#    'practice': 'N81013',
#    'bnf_name': 'Tiopex_Gel Eye Dps 1mg/g 0.4g Ud',
#    'nic': 14.98,
#    'act_cost': 13.9,
#    'quantity': 60}],
#  ('Fluclox Sod_Cap 500mg',
#   'P88009'): [{'bnf_code': '0501012G0AAABAB',
#    'items': 11,
#    'practice': 'P88009',
#    'bnf_name': 'Fluclox Sod_Cap 500mg',
#    'nic': 41.23,
#    'act_cost': 38.31,
#    'quantity': 532}],
#  ('Hylo-Care Sod Hyaluronate Eye Dps P/F 10',
#   'P85615'): [{'bnf_code': '21300000112',
#    'items': 1,
#    'practice': 'P85615',
#    'bnf_name': 'Hylo-Care Sod Hyaluronate Eye Dps P/F 10',
#    'nic': 10.3,
#    'act_cost': 9.55,
#    'quantity': 1}],
#  ('Alogliptin_Tab 25mg',
#   'P81668'): [{'bnf_code': '0601023AKAAACAC',
#    'items': 2,
#    'practice': 'P81668',
#    'bnf_name': 'Alogliptin_Tab 25mg',
#    'nic': 53.2,
#    'act_cost': 49.27,
#    'quantity': 56}],
#  ('Pioglitazone/Metformin HCl_Tab15mg/850mg',
#   'Y02961'): [{'bnf_code': '0601023W0AAAAAA',
#    'items': 2,
#    'practice': 'Y02961',
#    'bnf_name': 'Pioglitazone/Metformin HCl_Tab15mg/850mg',
#    'nic': 71.78,
#    'act_cost': 66.48,
#    'quantity': 112}],
#  ('Temazepam_Tab 20mg',
#   'N83637'): [{'bnf_code': '0401010T0AAANAN',
#    'items': 1,
#    'practice': 'N83637',
#    'bnf_name': 'Temazepam_Tab 20mg',
#    'nic': 1.91,
#    'act_cost': 1.78,
#    'quantity': 28}],
#  ('Spironol_Tab 25mg',
#   'A89603'): [{'bnf_code': '0202030S0AAATAT',
#    'items': 9,
#    'practice': 'A89603',
#    'bnf_name': 'Spironol_Tab 25mg',
#    'nic': 13.65,
#    'act_cost': 12.85,
#    'quantity': 294}],
#  ('Terbut Sulf_B/A Inha 500mcg (100 D)',
#   'P81100'): [{'bnf_code': '0301011V0AAALAL',
#    'items': 62,
#    'practice': 'P81100',
#    'bnf_name': 'Terbut Sulf_B/A Inha 500mcg (100 D)',
#    'nic': 491.32,
#    'act_cost': 455.42,
#    'quantity': 71}],
#  ('Gabapentin_Cap 100mg',
#   'B81112'): [{'bnf_code': '0408010G0AAAAAA',
#    'items': 33,
#    'practice': 'B81112',
#    'bnf_name': 'Gabapentin_Cap 100mg',
#    'nic': 49.61,
#    'act_cost': 48.84,
#    'quantity': 2600}],
#  ('Viscotears_Liq Gel 2mg/g',
#   'N81080'): [{'bnf_code': '1108010B0BBAAAB',
#    'items': 5,
#    'practice': 'N81080',
# ...
#    'items': 1,
#    'practice': 'P83020',
#    'bnf_name': 'Pizotifen Malate_Tab 500mcg',
#    'nic': 4.06,
#    'act_cost': 3.77,
#    'quantity': 56}],
#  ('Canesten_Combi Pess & Crm',
#   'L84033'): [{'bnf_code': '0702020F0BBANAK',
#    'items': 1,
#    'practice': 'L84033',
#    'bnf_name': 'Canesten_Combi Pess & Crm',
#    'nic': 8.21,
#    'act_cost': 7.63,
#    'quantity': 1}],
#  ('Active (Reagent)_Strips',
#   'C83613'): [{'bnf_code': '0601060D0BTAAA0',
#    'items': 1,
#    'practice': 'C83613',
#    'bnf_name': 'Active (Reagent)_Strips',
#    'nic': 9.95,
#    'act_cost': 9.22,
#    'quantity': 50}],
#  ('Evorel 50_Patch',
#   'L84056'): [{'bnf_code': '0604011G0BFAABL',
#    'items': 1,
#    'practice': 'L84056',
#    'bnf_name': 'Evorel 50_Patch',
#    'nic': 11.64,
#    'act_cost': 10.79,
#    'quantity': 24}],
#  ('BD Microfine+ Needles Pen Inj Screw On 5',
#   'B81077'): [{'bnf_code': '21010900600',
#    'items': 4,
#    'practice': 'B81077',
#    'bnf_name': 'BD Microfine+ Needles Pen Inj Screw On 5',
#    'nic': 87.21,
#    'act_cost': 80.77,
#    'quantity': 900}],
#  ('Forxiga_Tab 10mg',
#   'Y02274'): [{'bnf_code': '0601023AGBBABAB',
#    'items': 1,
#    'practice': 'Y02274',
#    'bnf_name': 'Forxiga_Tab 10mg',
#    'nic': 36.59,
#    'act_cost': 33.89,
#    'quantity': 28}],
#  ('Miconazole Nit_Pdr Spy 0.16% 100g CFF',
#   'P81681'): [{'bnf_code': '1310020N0AAAEAE',
#    'items': 1,
#    'practice': 'P81681',
#    'bnf_name': 'Miconazole Nit_Pdr Spy 0.16% 100g CFF',
#    'nic': 6.34,
#    'act_cost': 5.88,
#    'quantity': 2}],
#  ('Hydrocort_Tab 10mg',
#   'P81123'): [{'bnf_code': '0603020J0AAADAD',
#    'items': 16,
#    'practice': 'P81123',
#    'bnf_name': 'Hydrocort_Tab 10mg',
#    'nic': 2117.33,
#    'act_cost': 1961.03,
#    'quantity': 925}],
#  ('Marol_Tab 100mg M/R (Teva)',
#   'B81616'): [{'bnf_code': '040702040BNAFAC',
#    'items': 1,
#    'practice': 'B81616',
#    'bnf_name': 'Marol_Tab 100mg M/R (Teva)',
#    'nic': 6.48,
#    'act_cost': 6.11,
#    'quantity': 56}],
#  ('Liq Paraf Light_Bath Add 63.4%',
#   'Y02692'): [{'bnf_code': '1302011L0AAAIAI',
#    'items': 2,
#    'practice': 'Y02692',
#    'bnf_name': 'Liq Paraf Light_Bath Add 63.4%',
#    'nic': 13.71,
#    'act_cost': 12.71,
#    'quantity': 1500}],
#  ('Levothyrox Sod_Tab 25mcg',
#   'N83003'): [{'bnf_code': '0602010V0AABWBW',
#    'items': 105,
#    'practice': 'N83003',
#    'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#    'nic': 513.33,
#    'act_cost': 477.52,
#    'quantity': 4939}],
#  ('Doublebase_Gel',
#   'M83046'): [{'bnf_code': '130201000BBJGCA',
#    'items': 26,
#    'practice': 'M83046',
#    'bnf_name': 'Doublebase_Gel',
#    'nic': 168.54,
#    'act_cost': 156.37,
#    'quantity': 12800}],
#  ('Betameth Val_Crm 0.1%',
#   'M83100'): [{'bnf_code': '1304000F0AAAAAA',
#    'items': 8,
#    'practice': 'M83100',
#    'bnf_name': 'Betameth Val_Crm 0.1%',
#    'nic': 63.16,
#    'act_cost': 58.57,
#    'quantity': 660}],
#  ('Lamotrigine_Tab 25mg',
#   'A89026'): [{'bnf_code': '0408010H0AAACAC',
#    'items': 2,
#    'practice': 'A89026',
#    'bnf_name': 'Lamotrigine_Tab 25mg',
#    'nic': 3.54,
#    'act_cost': 3.3,
#    'quantity': 168}],
#  ('Olanzapine_Tab 5mg',
#   'B81091'): [{'bnf_code': '040201060AAAAAA',
#    'items': 2,
#    'practice': 'B81091',
#    'bnf_name': 'Olanzapine_Tab 5mg',
#    'nic': 1.9,
#    'act_cost': 1.78,
#    'quantity': 56}],
#  ('Sod Picosulf_Oral Soln 5mg/5ml S/F',
#   'P86619'): [{'bnf_code': '0106020P0AAABAB',
#    'items': 9,
#    'practice': 'P86619',
#    'bnf_name': 'Sod Picosulf_Oral Soln 5mg/5ml S/F',
#    'nic': 56.8,
#    'act_cost': 52.9,
#    'quantity': 2400}],
#  ('Clobetasol Prop_Oint 0.05%',
#   'F81740'): [{'bnf_code': '1304000G0AABABA',
#    'items': 4,
#    'practice': 'F81740',
#    'bnf_name': 'Clobetasol Prop_Oint 0.05%',
#    'nic': 36.98,
#    'act_cost': 34.28,
#    'quantity': 460}],
#  ('Fluconazole_Cap 50mg',
#   'D83012'): [{'bnf_code': '0502010B0AAAAAA',
#    'items': 5,
#    'practice': 'D83012',
#    'bnf_name': 'Fluconazole_Cap 50mg',
#    'nic': 10.92,
#    'act_cost': 10.16,
#    'quantity': 84}],
#  ('Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen',
#   'N82662'): [{'bnf_code': '0601011A0BBADAC',
#    'items': 12,
#    'practice': 'N82662',
#    'bnf_name': 'Ins NovoRapid_FlexPen 100u/ml 3ml Pf Pen',
#    'nic': 520.2,
#    'act_cost': 481.72,
#    'quantity': 85}],
#  ('Amlodipine_Tab 10mg',
#   'N82646'): [{'bnf_code': '0206020A0AAABAB',
#    'items': 140,
#    'practice': 'N82646',
#    'bnf_name': 'Amlodipine_Tab 10mg',
#    'nic': 123.25,
#    'act_cost': 116.25,
#    'quantity': 4368}],
#  ('Bicalutamide_Tab 50mg',
#   'N82065'): [{'bnf_code': '0803042A0AAAAAA',
#    'items': 1,
#    'practice': 'N82065',
#    'bnf_name': 'Bicalutamide_Tab 50mg',
#    'nic': 3.58,
#    'act_cost': 3.33,
#    'quantity': 56}],
#  ('Quetiapine_Tab 100mg',
#   'Y02521'): [{'bnf_code': '0402010ABAAACAC',
#    'items': 8,
#    'practice': 'Y02521',
#    'bnf_name': 'Quetiapine_Tab 100mg',
#    'nic': 8.75,
#    'act_cost': 8.99,
#    'quantity': 324}],
#  ('Symbicort_Turbohaler 100mcg/6mcg (120 D)',
#   'E84713'): [{'bnf_code': '0302000K0BDAAAL',
#    'items': 2,
#    'practice': 'E84713',
#    'bnf_name': 'Symbicort_Turbohaler 100mcg/6mcg (120 D)',
#    'nic': 66.0,
#    'act_cost': 61.12,
#    'quantity': 2}],
#  ('Accrete D3_Tab',
#   'B81077'): [{'bnf_code': '0906040G0BKAABS',
#    'items': 3,
#    'practice': 'B81077',
#    'bnf_name': 'Accrete D3_Tab',
#    'nic': 8.45,
#    'act_cost': 8.06,
#    'quantity': 172}],
#  ('Ins Levemir_FlexPen 100u/ml 3ml Pf Pen',
#   'L84033'): [{'bnf_code': '0601012X0BBABAB',
#    'items': 10,
#    'practice': 'L84033',
#    'bnf_name': 'Ins Levemir_FlexPen 100u/ml 3ml Pf Pen',
#    'nic': 504.0,
#    'act_cost': 466.69,
#    'quantity': 60}],
#  ('Vildagliptin/Metformin HCl_Tab50mg/850mg',
#   'P82640'): [{'bnf_code': '0601023Z0AAABAB',
#    'items': 6,
#    'practice': 'P82640',
#    'bnf_name': 'Vildagliptin/Metformin HCl_Tab50mg/850mg',
#    'nic': 209.32,
#    'act_cost': 194.05,
#    'quantity': 352}],
#  ('Morph Sulf_Tab 10mg M/R',
#   'N82646'): [{'bnf_code': '0407020Q0AAAKAK',
#    'items': 3,
#    'practice': 'N82646',
#    'bnf_name': 'Morph Sulf_Tab 10mg M/R',
#    'nic': 15.25,
#    'act_cost': 14.26,
#    'quantity': 176}],
#  ('Hydrocort_Crm 1%',
#   'E85605'): [{'bnf_code': '1304000V0AAADAD',
#    'items': 20,
#    'practice': 'E85605',
#    'bnf_name': 'Hydrocort_Crm 1%',
#    'nic': 43.2,
#    'act_cost': 40.28,
#    'quantity': 720}],
#  ('CliniFast 7.5cm x 5m (Blue) Stkntte Elas',
#   'Y03880'): [{'bnf_code': '20090000941',
#    'items': 29,
#    'practice': 'Y03880',
#    'bnf_name': 'CliniFast 7.5cm x 5m (Blue) Stkntte Elas',
#    'nic': 269.28,
#    'act_cost': 249.48,
#    'quantity': 72}],
#  ('Sotalol HCl_Tab 40mg',
#   'P81025'): [{'bnf_code': '0204000T0AAABAB',
#    'items': 2,
#    'practice': 'P81025',
#    'bnf_name': 'Sotalol HCl_Tab 40mg',
#    'nic': 3.06,
#    'act_cost': 2.86,
#    'quantity': 84}],
#  ('Salazopyrin-En_Tab 500mg',
#   'L82001'): [{'bnf_code': '0105010E0BBABAB',
#    'items': 3,
#    'practice': 'L82001',
#    'bnf_name': 'Salazopyrin-En_Tab 500mg',
#    'nic': 33.72,
#    'act_cost': 31.26,
#    'quantity': 448}],
#  ('Gliclazide_Tab 40mg',
#   'A89604'): [{'bnf_code': '0601021M0AAARAR',
#    'items': 13,
#    'practice': 'A89604',
#    'bnf_name': 'Gliclazide_Tab 40mg',
#    'nic': 43.68,
#    'act_cost': 40.99,
#    'quantity': 364}],
#  ('Zaluron XL_Tab 400mg',
#   'C82047'): [{'bnf_code': '0402010ABBHAEAY',
#    'items': 1,
#    'practice': 'C82047',
#    'bnf_name': 'Zaluron XL_Tab 400mg',
#    'nic': 46.99,
#    'act_cost': 43.61,
#    'quantity': 30}],
#  ('BD Viva Needles Pen Inj Screw On 4mm/32',
#   'N81024'): [{'bnf_code': '21010900607',
#    'items': 1,
#    'practice': 'N81024',
#    'bnf_name': 'BD Viva Needles Pen Inj Screw On 4mm/32',
#    'nic': 5.36,
#    'act_cost': 4.97,
#    'quantity': 90}],
#  ('Bard_Uriplan Leg Bag 30cm Inlet Tube 500',
#   'B81119'): [{'bnf_code': '22500505006',
#    'items': 4,
#    'practice': 'B81119',
#    'bnf_name': 'Bard_Uriplan Leg Bag 30cm Inlet Tube 500',
#    'nic': 117.96,
#    'act_cost': 109.2,
#    'quantity': 40}],
#  ('Water For Inj_10ml Amp',
#   'C82071'): [{'bnf_code': '0902021X0AAADAD',
#    'items': 5,
#    'practice': 'C82071',
#    'bnf_name': 'Water For Inj_10ml Amp',
#    'nic': 15.54,
#    'act_cost': 14.45,
#    'quantity': 60}],
#  ('Co-Codamol_Tab 8mg/500mg',
#   'M91025'): [{'bnf_code': '0407010F0AAAAAA',
#    'items': 21,
#    'practice': 'M91025',
#    'bnf_name': 'Co-Codamol_Tab 8mg/500mg',
#    'nic': 56.91,
#    'act_cost': 53.56,
#    'quantity': 1916}],
#  ('Fluticasone/Formoterol_Inh 250/10mcg120D',
#   'B83661'): [{'bnf_code': '0302000N0AABKBK',
#    'items': 9,
#    'practice': 'B83661',
#    'bnf_name': 'Fluticasone/Formoterol_Inh 250/10mcg120D',
#    'nic': 637.84,
#    'act_cost': 590.59,
#    'quantity': 14}],
#  ('Aspen_Sorbaderm No-Sting Barrier Film 1m',
#   'P81051'): [{'bnf_code': '23800298002',
#    'items': 2,
#    'practice': 'P81051',
#    'bnf_name': 'Aspen_Sorbaderm No-Sting Barrier Film 1m',
#    'nic': 22.25,
#    'act_cost': 20.61,
#    'quantity': 25}],
#  ('Fluoxetine HCl_Cap 20mg',
#   'E82045'): [{'bnf_code': '0403030E0AAAAAA',
#    'items': 39,
#    'practice': 'E82045',
#    'bnf_name': 'Fluoxetine HCl_Cap 20mg',
#    'nic': 46.56,
#    'act_cost': 45.99,
#    'quantity': 1607}],
#  ('Enalapril Mal_Tab 20mg',
#   'Y02274'): [{'bnf_code': '0205051I0AAADAD',
#    'items': 1,
#    'practice': 'Y02274',
#    'bnf_name': 'Enalapril Mal_Tab 20mg',
#    'nic': 0.98,
#    'act_cost': 0.92,
#    'quantity': 28}],
#  ('Erythromycin_Ethylsuc Susp 125mg/5ml S/F',
#   'M91034'): [{'bnf_code': '0501050H0AAALAL',
#    'items': 1,
#    'practice': 'M91034',
#    'bnf_name': 'Erythromycin_Ethylsuc Susp 125mg/5ml S/F',
#    'nic': 7.12,
#    'act_cost': 6.6,
#    'quantity': 200}],
#  ('Ivabradine_Tab 5mg',
#   'C84691'): [{'bnf_code': '0206030Y0AAAAAA',
#    'items': 1,
#    'practice': 'C84691',
#    'bnf_name': 'Ivabradine_Tab 5mg',
#    'nic': 40.17,
#    'act_cost': 37.2,
#    'quantity': 56}],
#  ('Diclofenac Sod_Gel 1.16%',
#   'M88619'): [{'bnf_code': '1003020U0AAAAAA',
#    'items': 16,
#    'practice': 'M88619',
#    'bnf_name': 'Diclofenac Sod_Gel 1.16%',
#    'nic': 101.34,
#    'act_cost': 94.01,
#    'quantity': 1800}],
#  ('Rosuvastatin Calc_Tab 10mg',
#   'A81049'): [{'bnf_code': '0212000AAAAAAAA',
#    'items': 5,
#    'practice': 'A81049',
#    'bnf_name': 'Rosuvastatin Calc_Tab 10mg',
#    'nic': 108.18,
#    'act_cost': 100.21,
#    'quantity': 168}],
#  ('BuTrans_Transdermal Patch 10mcg/hr',
#   'P92607'): [{'bnf_code': '0407020B0BEABAI',
#    'items': 1,
#    'practice': 'P92607',
#    'bnf_name': 'BuTrans_Transdermal Patch 10mcg/hr',
#    'nic': 31.55,
#    'act_cost': 29.22,
#    'quantity': 4}],
#  ('Co-Codamol Eff_Tab 30mg/500mg',
#   'P81668'): [{'bnf_code': '0407010F0AAAFAF',
#    'items': 13,
#    'practice': 'P81668',
#    'bnf_name': 'Co-Codamol Eff_Tab 30mg/500mg',
#    'nic': 92.15,
#    'act_cost': 86.17,
#    'quantity': 1064}],
#  ('Dutasteride_Cap 500mcg',
#   'M83713'): [{'bnf_code': '0604020B0AAAAAA',
#    'items': 1,
#    'practice': 'M83713',
#    'bnf_name': 'Dutasteride_Cap 500mcg',
#    'nic': 13.63,
#    'act_cost': 12.73,
#    'quantity': 28}],
#  ('Sinemet-Plus_Tab 125mg',
#   'J81046'): [{'bnf_code': '0409010N0BBACAB',
#    'items': 3,
#    'practice': 'J81046',
#    'bnf_name': 'Sinemet-Plus_Tab 125mg',
#    'nic': 75.73,
#    'act_cost': 70.45,
#    'quantity': 588}],
#  ('Cyclizine HCl_Tab 50mg',
#   'H84030'): [{'bnf_code': '0406000F0AAACAC',
#    'items': 9,
#    'practice': 'H84030',
#    'bnf_name': 'Cyclizine HCl_Tab 50mg',
#    'nic': 36.3,
#    'act_cost': 34.52,
#    'quantity': 498}],
#  ('Dansac_Non Sting Adh Remover A/Spy 50ml',
#   'N81057'): [{'bnf_code': '23150701503',
#    'items': 1,
#    'practice': 'N81057',
#    'bnf_name': 'Dansac_Non Sting Adh Remover A/Spy 50ml',
#    'nic': 28.2,
#    'act_cost': 26.11,
#    'quantity': 3}],
#  ('Lorazepam_Tab 1mg',
#   'M85669'): [{'bnf_code': '0401020P0AAABAB',
#    'items': 11,
#    'practice': 'M85669',
#    'bnf_name': 'Lorazepam_Tab 1mg',
#    'nic': 70.25,
#    'act_cost': 66.16,
#    'quantity': 330}],
#  ('Travoprost_Eye Dps 40mcg/ml',
#   'A89026'): [{'bnf_code': '1106000AEAAAAAA',
#    'items': 8,
#    'practice': 'A89026',
#    'bnf_name': 'Travoprost_Eye Dps 40mcg/ml',
#    'nic': 87.6,
#    'act_cost': 81.2,
#    'quantity': 16}],
#  ('Folic Acid_Tab 400mcg',
#   'M85078'): [{'bnf_code': '0901020G0AABFBF',
#    'items': 14,
#    'practice': 'M85078',
#    'bnf_name': 'Folic Acid_Tab 400mcg',
#    'nic': 36.02,
#    'act_cost': 33.72,
#    'quantity': 1196}],
#  ('Xailin Carbomer Eye Gel 10g',
#   'M85070'): [{'bnf_code': '21300000704',
#    'items': 1,
#    'practice': 'M85070',
#    'bnf_name': 'Xailin Carbomer Eye Gel 10g',
#    'nic': 3.25,
#    'act_cost': 3.02,
#    'quantity': 1}],
#  ('Tegretol_Tab 400mg',
#   'P84637'): [{'bnf_code': '0408010C0BBACAD',
#    'items': 1,
#    'practice': 'P84637',
#    'bnf_name': 'Tegretol_Tab 400mg',
#    'nic': 10.04,
#    'act_cost': 9.31,
#    'quantity': 112}],
#  ('Cefalexin_Cap 250mg',
#   'N81091'): [{'bnf_code': '0501021L0AAAAAA',
#    'items': 2,
#    'practice': 'N81091',
#    'bnf_name': 'Cefalexin_Cap 250mg',
#    'nic': 2.62,
#    'act_cost': 2.45,
#    'quantity': 56}],
#  ('Carbocisteine_Cap 375mg',
#   'C82082'): [{'bnf_code': '0307000J0AAAAAA',
#    'items': 19,
#    'practice': 'C82082',
#    'bnf_name': 'Carbocisteine_Cap 375mg',
#    'nic': 199.21,
#    'act_cost': 185.35,
#    'quantity': 2554}],
#  ('Hydroxycarbamide_Cap 500mg',
#   'F81158'): [{'bnf_code': '0801050P0AAAAAA',
#    'items': 1,
#    'practice': 'F81158',
#    'bnf_name': 'Hydroxycarbamide_Cap 500mg',
#    'nic': 12.12,
#    'act_cost': 11.23,
#    'quantity': 100}],
#  ('Carbimazole_Tab 5mg',
#   'H81615'): [{'bnf_code': '0602020D0AAAAAA',
#    'items': 2,
#    'practice': 'H81615',
#    'bnf_name': 'Carbimazole_Tab 5mg',
#    'nic': 97.3,
#    'act_cost': 90.2,
#    'quantity': 156}],
#  ('FreeStyle Optium (Reagent)_Strips',
#   'H85653'): [{'bnf_code': '0601060D0BJADA0',
#    'items': 2,
#    'practice': 'H85653',
#    'bnf_name': 'FreeStyle Optium (Reagent)_Strips',
#    'nic': 63.48,
#    'act_cost': 58.79,
#    'quantity': 200}],
#  ('Donepezil HCl_Tab 10mg',
#   'C87005'): [{'bnf_code': '0411000D0AAABAB',
#    'items': 71,
#    'practice': 'C87005',
#    'bnf_name': 'Donepezil HCl_Tab 10mg',
#    'nic': 83.26,
#    'act_cost': 78.38,
#    'quantity': 2100}],
#  ('Ins Lantus SoloStar_100u/ml 3ml Pf Pen',
#   'Y03051'): [{'bnf_code': '0601012V0BBAEAD',
#    'items': 3,
#    'practice': 'Y03051',
#    'bnf_name': 'Ins Lantus SoloStar_100u/ml 3ml Pf Pen',
#    'nic': 207.5,
#    'act_cost': 192.13,
#    'quantity': 25}],
#  ('Domperidone_Tab 10mg',
#   'C84691'): [{'bnf_code': '0406000J0AAAJAJ',
#    'items': 2,
#    'practice': 'C84691',
#    'bnf_name': 'Domperidone_Tab 10mg',
#    'nic': 1.42,
#    'act_cost': 1.34,
#    'quantity': 60}],
#  ('Madopar_Tab Disper 50mg/12.5mg',
#   'P83015'): [{'bnf_code': '0409010K0BBAJAE',
#    'items': 2,
#    'practice': 'P83015',
#    'bnf_name': 'Madopar_Tab Disper 50mg/12.5mg',
#    'nic': 9.2,
#    'act_cost': 8.64,
#    'quantity': 156}],
#  ('Clonazepam_Tab 500mcg',
#   'P85613'): [{'bnf_code': '0408010F0AAABAB',
#    'items': 5,
#    'practice': 'P85613',
#    'bnf_name': 'Clonazepam_Tab 500mcg',
#    'nic': 87.45,
#    'act_cost': 81.52,
#    'quantity': 308}],
#  ('Clotrimazole_Pess 500mg/Crm 2%',
#   'P81002'): [{'bnf_code': '0702020F0AAAKAK',
#    'items': 9,
#    'practice': 'P81002',
#    'bnf_name': 'Clotrimazole_Pess 500mg/Crm 2%',
#    'nic': 83.36,
#    'act_cost': 77.39,
#    'quantity': 16}],
#  ('Fludrocort Acet_Tab 100mcg',
#   'P83603'): [{'bnf_code': '0603010I0AAACAC',
#    'items': 5,
#    'practice': 'P83603',
#    'bnf_name': 'Fludrocort Acet_Tab 100mcg',
#    'nic': 141.0,
#    'act_cost': 131.08,
#    'quantity': 141}],
#  ('Levothyrox Sod_Tab 25mcg',
#   'B81014'): [{'bnf_code': '0602010V0AABWBW',
#    'items': 184,
#    'practice': 'B81014',
#    'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#    'nic': 596.09,
#    'act_cost': 555.41,
#    'quantity': 5735}],
#  ('NovoFine Needles Pen Inj Screw On 6mm',
#   'P92005'): [{'bnf_code': '21010900705',
#    'items': 6,
#    'practice': 'P92005',
#    'bnf_name': 'NovoFine Needles Pen Inj Screw On 6mm',
#    'nic': 91.14,
#    'act_cost': 84.45,
#    'quantity': 700}],
#  ('Tears Naturale_Eye Dps',
#   'N82662'): [{'bnf_code': '1108010F0BDAAA4',
#    'items': 3,
#    'practice': 'N82662',
#    'bnf_name': 'Tears Naturale_Eye Dps',
#    'nic': 13.23,
#    'act_cost': 12.28,
#    'quantity': 105}],
#  ('Lyrica_Cap 225mg',
#   'B81070'): [{'bnf_code': '0408010AEBBAHAI',
#    'items': 1,
#    'practice': 'B81070',
#    'bnf_name': 'Lyrica_Cap 225mg',
#    'nic': 64.4,
#    'act_cost': 59.63,
#    'quantity': 56}],
#  ...}

# %%
groups = group_by_field(scripts, ('bnf_name',))
test_max_item = [max ([(sum([member['items'] for member in group]), name[0]) for name, group in groups.items()]) [::-1]]

assert test_max_item == max_item

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
print(scripts[0])
print()
print(practices[0])
# Out:
# {'bnf_code': '0101010G0AAABAB', 'items': 2, 'practice': 'N81013', 'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F', 'nic': 5.98, 'act_cost': 5.56, 'quantity': 1000}
#
# {'code': 'A81001', 'name': 'THE DENSHAM SURGERY', 'addr_1': 'THE HEALTH CENTRE', 'addr_2': 'LAWSON STREET', 'borough': 'STOCKTON ON TEES', 'village': 'CLEVELAND', 'post_code': 'TS18 1HU'}

# %%
practice_postal = {}
for practice in practices:
    code=practice['code']
#     if practice['code'] not in practice_postal:
#         practice_postal[practice['code']] = ...
#     if practice['code'] in practice_postal
#         practice_postal[practice['code']] = ...
    if code not in practice_postal:
        practice_postal[code]=practice['post_code']
    if code in practice_postal:
        practice_postal[code]=min(practice_postal[code],practice['post_code'])

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:]
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
joined[0]
# Out:
# {'bnf_code': '0101010G0AAABAB',
#  'items': 2,
#  'practice': 'N81013',
#  'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#  'nic': 5.98,
#  'act_cost': 5.56,
#  'quantity': 1000,
#  'post_code': 'SK11 6JL'}

# %%
pc_grouped=list(group_by_field(joined,('post_code',)).items())
items_by_post=[(pc[0],sum(group['items'] for group in groups)) for pc, groups in pc_grouped]
items_by_post = sorted(items_by_post)

# %%
postal_totals = items_by_post[:100]

grader.score.pw__postal_totals(postal_totals)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.

# %% [markdown]
# Now we need to calculate the total items of each `'bnf_name'` prescribed in each `'post_code'`. Use the techniques we developed in the previous questions to calculate these totals. You should have 141196 `('post_code', 'bnf_name')` groups.

# %%
p_b_grouped=group_by_field(joined,('post_code','bnf_name')).items()
total_items_by_bnf_post = {name: sum(group['items'] for group in groups) for name,groups in p_b_grouped}
assert len(total_items_by_bnf_post) == 141196

# %% [markdown]
# Let's use `total_items` to find the maximum item total for each postal code. To do this, we will want to regroup `total_items_by_bnf_post` by `'post_code'` only, not by `('post_code', 'bnf_name')`. First let's turn `total_items` into a list of dictionaries (similar to `scripts` or `practices`) and then group it by `'post_code'`. You should have 118 groups in the resulting `total_items_by_post` after grouping `total_items` by `'post_code'`.

# %%
# p_grouped=group_by_field(joined,('post_code',)).items()
# total_items_by_post = {name: sum(group['items'] for group in groups) for name,groups in p_grouped}
total_items= [{'post_code': tup[0], 'bnf_name': tup[1], 'total' : tot} for tup, tot in list(total_items_by_bnf_post.items())]
total_items_by_post = group_by_field(total_items, ('post_code',))
assert len(total_items_by_post) == 118

# %% [markdown]
# Now we will aggregate the groups in `total_by_item_post` to create `max_item_by_post`. Some `'bnf_name'` have the same item total within a given postal code. Therefore, if more than one `'bnf_name'` has the maximum item total in a given postal code, we'll take the alphabetically first `'bnf_name'`. We can do this by [sorting](https://docs.python.org/2.7/howto/sorting.html) each group according to the item total and `'bnf_name'`.

# %%
max_item_by_post = [sorted(group,key=lambda mem:(-mem['total'],mem['bnf_name']))[0]
                   for group in total_items_by_post.values()]

# %% [markdown]
# In order to express the item totals as a proportion of the total amount of items prescribed across all `'bnf_name'` in a postal code, we'll need to use the total items prescribed that we previously calculated as `items_by_post`. Calculate the proportions for the most common `'bnf_names'` for each postal code. Format your answer as a list of tuples: `[(post_code, bnf_name, total)]`

# %%
# items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100

result= [(item['post_code'], item['bnf_name'],item['total'] /dict(items_by_post)[item['post_code']]) 
         for item in max_item_by_post]
# Take the first 100 elements and pass it to the grader
items_by_region = sorted(result)[:100]

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
