# %%
# %logstop
# %logstart -rtq ~/.logs/ml.py append
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %% [markdown]
# # ML Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to create effective machine learning models for making predictions. We will be working with nursing home inspection data from the United States, predicting which providers may be fined and for how much.
#
# ## Scoring
#
# In this miniproject you will often submit your model's `predict` or `predict_proba` method to the grader. The grader will assess the performance of your model using a scoring metric, comparing it against the score of a reference model. We will use the [average precision score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html). If your model performs better than the reference solution, then you can score higher than 1.0.
#
# **Note:** If you use an estimator that relies on random draws (like a `RandomForestClassifier`) you should set the `random_state=` to an integer so that your results are reproducible.
#
# ## Downloading the data
#
# We can download the data set from Amazon S3:

# %%
# %%bash
# mkdir data
# wget http://dataincubator-wqu.s3.amazonaws.com/mldata/providers-train.csv -nc -P ./ml-data
# wget http://dataincubator-wqu.s3.amazonaws.com/mldata/providers-metadata.csv -nc -P ./ml-data
# Out:
# --2021-04-25 14:52:16--  http://dataincubator-wqu.s3.amazonaws.com/mldata/providers-train.csv
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.216.176.251
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.216.176.251|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3398120 (3.2M) [text/csv]
# Saving to: ‘./ml-data/providers-train.csv’
#
#      0K .......... .......... .......... .......... ..........  1% 3.72M 1s
#     50K .......... .......... .......... .......... ..........  3% 7.23M 1s
#    100K .......... .......... .......... .......... ..........  4% 5.74M 1s
#    150K .......... .......... .......... .......... ..........  6% 47.1M 0s
#    200K .......... .......... .......... .......... ..........  7% 11.8M 0s
#    250K .......... .......... .......... .......... ..........  9% 31.3M 0s
#    300K .......... .......... .......... .......... .......... 10% 28.9M 0s
#    350K .......... .......... .......... .......... .......... 12%  104M 0s
#    400K .......... .......... .......... .......... .......... 13% 16.7M 0s
#    450K .......... .......... .......... .......... .......... 15% 42.2M 0s
#    500K .......... .......... .......... .......... .......... 16% 48.0M 0s
#    550K .......... .......... .......... .......... .......... 18% 87.8M 0s
#    600K .......... .......... .......... .......... .......... 19%  287M 0s
#    650K .......... .......... .......... .......... .......... 21%  251M 0s
#    700K .......... .......... .......... .......... .......... 22%  258M 0s
#    750K .......... .......... .......... .......... .......... 24%  271M 0s
#    800K .......... .......... .......... .......... .......... 25%  285M 0s
#    850K .......... .......... .......... .......... .......... 27% 8.22M 0s
#    900K .......... .......... .......... .......... .......... 28% 22.4M 0s
#    950K .......... .......... .......... .......... .......... 30% 22.9M 0s
#   1000K .......... .......... .......... .......... .......... 31% 29.3M 0s
#   1050K .......... .......... .......... .......... .......... 33%  211M 0s
#   1100K .......... .......... .......... .......... .......... 34%  224M 0s
#   1150K .......... .......... .......... .......... .......... 36%  116M 0s
#   1200K .......... .......... .......... .......... .......... 37% 20.2M 0s
#   1250K .......... .......... .......... .......... .......... 39% 52.7M 0s
#   1300K .......... .......... .......... .......... .......... 40% 41.1M 0s
#   1350K .......... .......... .......... .......... .......... 42% 41.4M 0s
#   1400K .......... .......... .......... .......... .......... 43% 37.8M 0s
#   1450K .......... .......... .......... .......... .......... 45% 31.1M 0s
#   1500K .......... .......... .......... .......... .......... 46% 34.4M 0s
#   1550K .......... .......... .......... .......... .......... 48% 43.1M 0s
#   1600K .......... .......... .......... .......... .......... 49% 47.7M 0s
#   1650K .......... .......... .......... .......... .......... 51% 38.2M 0s
#   1700K .......... .......... .......... .......... .......... 52%  214M 0s
#   1750K .......... .......... .......... .......... .......... 54%  244M 0s
#   1800K .......... .......... .......... .......... .......... 55%  154M 0s
#   1850K .......... .......... .......... .......... .......... 57%  203M 0s
#   1900K .......... .......... .......... .......... .......... 58%  277M 0s
#   1950K .......... .......... .......... .......... .......... 60%  279M 0s
#   2000K .......... .......... .......... .......... .......... 61%  206M 0s
#   2050K .......... .......... .......... .......... .......... 63%  239M 0s
#   2100K .......... .......... .......... .......... .......... 64%  282M 0s
#   2150K .......... .......... .......... .......... .......... 66%  281M 0s
#   2200K .......... .......... .......... .......... .......... 67%  236M 0s
#   2250K .......... .......... .......... .......... .......... 69%  221M 0s
#   2300K .......... .......... .......... .......... .......... 70%  239M 0s
#   2350K .......... .......... .......... .......... .......... 72%  196M 0s
#   2400K .......... .......... .......... .......... .......... 73%  212M 0s
#   2450K .......... .......... .......... .......... .......... 75%  279M 0s
#   2500K .......... .......... .......... .......... .......... 76% 59.5M 0s
#   2550K .......... .......... .......... .......... .......... 78% 48.3M 0s
#   2600K .......... .......... .......... .......... .......... 79% 45.6M 0s
#   2650K .......... .......... .......... .......... .......... 81% 53.0M 0s
#   2700K .......... .......... .......... .......... .......... 82% 34.2M 0s
#   2750K .......... .......... .......... .......... .......... 84% 49.7M 0s
#   2800K .......... .......... .......... .......... .......... 85% 47.5M 0s
#   2850K .......... .......... .......... .......... .......... 87% 46.1M 0s
#   2900K .......... .......... .......... .......... .......... 88% 52.8M 0s
#   2950K .......... .......... .......... .......... .......... 90%  114M 0s
#   3000K .......... .......... .......... .......... .......... 91%  231M 0s
#   3050K .......... .......... .......... .......... .......... 93%  247M 0s
#   3100K .......... .......... .......... .......... .......... 94%  285M 0s
#   3150K .......... .......... .......... .......... .......... 96%  245M 0s
#   3200K .......... .......... .......... .......... .......... 97%  232M 0s
#   3250K .......... .......... .......... .......... .......... 99%  276M 0s
#   3300K .......... ........                                   100%  282M=0.08s
#
# 2021-04-25 14:52:16 (38.4 MB/s) - ‘./ml-data/providers-train.csv’ saved [3398120/3398120]
#
# --2021-04-25 14:52:16--  http://dataincubator-wqu.s3.amazonaws.com/mldata/providers-metadata.csv
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.217.84.188
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.217.84.188|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9401 (9.2K) [text/csv]
# Saving to: ‘./ml-data/providers-metadata.csv’
#
#      0K .........                                             100% 1.30M=0.007s
#
# 2021-04-25 14:52:16 (1.30 MB/s) - ‘./ml-data/providers-metadata.csv’ saved [9401/9401]

# %% [markdown]
# We'll load the data into a Pandas DataFrame. Several columns will become target labels in future questions. Let's pop those columns out from the data, and drop related columns that are neither targets nor reasonable features (i.e. we don't wouldn't know how many times a facility denied payment before knowing whether it was fined).
#
# The data has many columns. We have also provided a data dictionary.

# %%
import numpy as np
import pandas as pd

# %%
metadata = pd.read_csv('./ml-data/providers-metadata.csv')
metadata.head(40)
# Out:
#                  Variable                                              Label  \
# 0                 PROVNUM                            Federal Provider Number
# 1                PROVNAME                                      Provider Name
# 2                 ADDRESS                                   Provider Address
# 3                    CITY                                      Provider City
# 4                   STATE                                     Provider State
# 5                     ZIP                                  Provider Zip Code
# 6                   PHONE                              Provider Phone Number
# 7              COUNTY_SSA                                Provider SSA County
# 8             COUNTY_NAME                               Provider County Name
# 9               OWNERSHIP                                     Ownership Type
# 10                BEDCERT                           Number of Certified Beds
# 11                 RESTOT                Average Number of Residents per Day
# 12          CERTIFICATION                                      Provider Type
# 13                 INHOSP                       Provider Resides in Hospital
# 14                    LBN                                Legal Business Name
# 15     PARTICIPATION_DATE  Date First Approved to Provide Medicare and Me...
# 16             CCRC_FACIL               Continuing Care Retirement Community
# 17                    SFF                             Special Focus Facility
# 18              OLDSURVEY  Most Recent Health Inspection More Than 2 Year...
# 19        CHOW_LAST_12MOS       Provider Changed Ownership in Last 12 Months
# 20          resfamcouncil                 With a Resident and Family Council
# 21       sprinkler_status  Automatic Sprinkler Systems in All Required Areas
# 22         overall_rating                                     Overall Rating
# 23      overall_rating_fn                            Overall Rating Footnote
# 24          survey_rating                           Health Inspection Rating
# 25       survey_rating_fn                  Health Inspection Rating Footnote
# 26         quality_rating                                          QM Rating
# 27      quality_rating_fn                                 QM Rating Footnote
# 28        staffing_rating                                    Staffing Rating
# 29     staffing_rating_fn                           Staffing Rating Footnote
# 30     RN_staffing_rating                                 RN Staffing Rating
# 31  rn_staffing_rating_fn                        RN Staffing Rating Footnote
# 32          STAFFING_FLAG                         Reported Staffing Footnote
# 33       PT_STAFFING_FLAG               Physical Therapist Staffing Footnote
# 34                 AIDHRD  Reported Nurse Aide Staffing Hours per Residen...
# 35                 VOCHRD   Reported LPN Staffing Hours per Resident per Day
# 36                  RNHRD    Reported RN Staffing Hours per Resident per Day
# 37              TOTLICHRD  Reported Licensed Staffing Hours per Resident ...
# 38                 TOTHRD  Reported Total Nurse Staffing Hours per Reside...
# 39                  PTHRD  Reported Physical Therapist Staffing Hours per...
#
#                                           Description  \
# 0                             Federal Provider Number
# 1                                       Provider Name
# 2                                    Provider Address
# 3                                       Provider City
# 4                                      Provider State
# 5                                   Provider Zip Code
# 6                               Provider Phone Number
# 7                                     SSA county code
# 8                                Provider County Name
# 9   Nature of organization that operates a provide...
# 10                 Number of Federally Certified Beds
# 11  Average number of residents based on MDS daily...
# 12      Category which is most indicative of provider
# 13             Facility Resides in Hospital Indicator
# 14                                Legal Business Name
# 15  Date First Approved to Provide Medicare/Medica...
# 16     Continuing Care Retirement Community Indicator
# 17                   Special Focus Facility Indicator
# 18  Most recent survey occurred more than 2 years ...
# 19  Facility Changed Ownership in Last 12 Months I...
# 20                 With a Resident and Family Council
# 21  Automatic Sprinkler Systems in All Required Areas
# 22                                     Overall Rating
# 23                            Overall Rating Footnote
# 24                           Health Inspection Rating
# 25                  Health Inspection Rating Footnote
# 26                                          QM Rating
# 27                                 QM Rating Footnote
# 28                                    Staffing Rating
# 29                           Staffing Rating Footnote
# 30                                 RN Staffing Rating
# 31                        RN Staffing Rating Footnote
# 32                         Reported Staffing Footnote
# 33                 Physical Therapy Staffing Footnote
# 34  Reported Nurse Aide Staffing - Hours per Resid...
# 35  Reported LPN Staffing - Hours per Resident per...
# 36  Reported RN Staffing - Hours per Resident per Day
# 37  Reported Licensed Staffing - Hours per Residen...
# 38  Reported Total Nurse Staffing - Hours per Resi...
# 39  Reported Physical Therapy Staffing - Hours per...
#
#                                   Format
# 0              6 alphanumeric characters
# 1                                   text
# 2                                   text
# 3                                   text
# 4        2-character postal abbreviation
# 5                       5-digit zip code
# 6                  10 digit phone number
# 7                       3-digit SSA code
# 8                                   text
# 9                                   text
# 10                               integer
# 11   number with one decimal place 000.0
# 12                                  text
# 13                                   Y/N
# 14                                  text
# 15                                  date
# 16                                   Y/N
# 17                                   Y/N
# 18                                   Y/N
# 19                                   Y/N
# 20          Resident, Family, Both, None
# 21  Yes, Partial, No, Data Not Available
# 22                 one-digit, values 1-5
# 23                       blank or text
# 24                 one-digit, values 1-5
# 25                       blank or text
# 26                 one-digit, values 1-5
# 27                       blank or text
# 28                 one-digit, values 1-5
# 29                       blank or text
# 30                 one-digit, values 1-5
# 31                       blank or text
# 32    blank or text (Data Not Available)
# 33    blank or text (Data Not Available)
# 34   real number, up to 5 decimal places
# 35   real number, up to 5 decimal places
# 36   real number, up to 5 decimal places
# 37   real number, up to 5 decimal places
# 38   real number, up to 5 decimal places
# 39   real number, up to 5 decimal places

# %%
metadata.tail(40)
# Out:
#                      Variable  \
# 39                      PTHRD
# 40                   exp_aide
# 41                    exp_lpn
# 42                     exp_rn
# 43                  exp_total
# 44                   adj_aide
# 45                    adj_lpn
# 46                     adj_rn
# 47                  adj_total
# 48                R_SRVY_DT_F
# 49           R_TOT_HTH_DFCNCY
# 50                R_HTH_SVRTY
# 51                R_HTH_SCOPE
# 52             PREV_SRVY_DT_F
# 53        PREV_TOT_HTH_DFCNCY
# 54        CYCLE_1_SURVEY_DATE
# 55               cycle_1_defs
# 56          cycle_1_nfromdefs
# 57          cycle_1_nfromcomp
# 58         cycle_1_defs_score
# 59           cycle_1_numrevis
# 60      cycle_1_revisit_score
# 61        cycle_1_total_score
# 62        cycle_2_survey_date
# 63               cycle_2_defs
# 64          cycle_2_nfromdefs
# 65          cycle_2_nfromcomp
# 66         cycle_2_defs_score
# 67           cycle_2_numrevis
# 68      cycle_2_revisit_score
# 69        cycle_2_total_score
# 70  WEIGHTED_ALL_CYCLES_SCORE
# 71               incident_cnt
# 72                 cmplnt_cnt
# 73                   FINE_CNT
# 74                   FINE_TOT
# 75                 PAYDEN_CNT
# 76             TOT_PENLTY_CNT
# 77                   LOCATION
# 78                   FILEDATE
#
#                                                 Label  \
# 39  Reported Physical Therapist Staffing Hours per...
# 40  Expected Nurse Aide Staffing Hours per Residen...
# 41   Expected LPN Staffing Hours per Resident per Day
# 42    Expected RN Staffing Hours per Resident per Day
# 43  Expected Total Nurse Staffing Hours per Reside...
# 44  Adjusted Nurse Aide Staffing Hours per Residen...
# 45   Adjusted LPN Staffing Hours per Resident per Day
# 46    Adjusted RN Staffing Hours per Resident per Day
# 47  Adjusted Total Nurse Staffing Hours per Reside...
# 48               Health Survey Date Under New Process
# 49  Number of Health Deficiencies on Survey Under ...
# 50  Severity of Most Severe Deficiency Cited Under...
# 51  Residents Affected or Scope of Broadest Scope ...
# 52        Date of Previous Standard Health Inspection
# 53  Number of Health Deficiencies on Previous Stan...
# 54         Rating cycle 1 Standard Survey Health Date
# 55  Rating cycle 1 Total Number of Health Deficien...
# 56  Rating cycle 1 Number of Standard Health Defic...
# 57  Rating cycle 1 Number of Complaint Health Defi...
# 58             Rating cycle 1 Health Deficiency Score
# 59           Rating cycle 1 Number of Health Revisits
# 60                Rating cycle 1 Health Revisit Score
# 61                  Rating cycle 1 Total Health Score
# 62         Rating cycle 2 Standard Health Survey Date
# 63  Rating cycle 2 Total Number of Health Deficien...
# 64  Rating cycle 2 Number of Standard Health Defic...
# 65  Rating cycle 2 Number of Complaint Health Defi...
# 66             Rating cycle 2 Health Deficiency Score
# 67           Rating cycle 2 Number of Health Revisits
# 68                Rating cycle 2 Health Revisit Score
# 69                  Rating cycle 2 Total Health Score
# 70                 Total Weighted Health Survey Score
# 71              Number of Facility Reported Incidents
# 72                 Number of Substantiated Complaints
# 73                                    Number of Fines
# 74                   Total Amount of Fines in Dollars
# 75                          Number of Payment Denials
# 76                          Total Number of Penalties
# 77                                           Location
# 78                                    Processing Date
#
#                                           Description  \
# 39  Reported Physical Therapy Staffing - Hours per...
# 40  Expected Nurse Aide Staffing - Hours per Resid...
# 41  Expected LPN Staffing - Hours per Resident per...
# 42  Expected RN Staffing - Hours per Resident per Day
# 43  Expected Total Nurse Staffing - Hours per Resi...
# 44  Adjusted Nurse Aide Staffing - Hours per Resid...
# 45  Adjusted LPN Staffing - Hours per Resident per...
# 46  Adjusted RN Staffing - Hours per Resident per Day
# 47  Adjusted Total Nurse Staffing - Hours per Resi...
# 48  Date of most recent health inspection occurrin...
# 49  Number of health deficiency citations on most ...
# 50  Severity of most severe deficiency cited on he...
# 51  Scope of deficiency with greatest scope cited ...
# 52  Date of most recent health inspection occurrin...
# 53  Number of health deficiency citations on most ...
# 54  Date of Rating cycle 1 Standard Health Survey ...
# 55  Total Number of Health Deficiencies in Rating ...
# 56  Number of Health Deficiencies from the Standar...
# 57  Number of Health Deficiencies from Complaint S...
# 58           Rating cycle 1 - Health Deficiency Score
# 59  Number of Health Survey Repeat-Revisits for Ra...
# 60  Points Associated with Health Survey Repeat Re...
# 61     Rating cycle 1 - Total Health Inspection Score
# 62  Date of Rating cycle 2 Standard Health Survey ...
# 63  Total Number of Health Deficiencies in Rating ...
# 64  Number of Health Deficiencies from the Standar...
# 65  Number of Health Deficiencies from Complaint S...
# 66           Rating cycle 2 - Health Deficiency Score
# 67  Number of Health Survey Repeat-Revisits for Ra...
# 68  Points Associated with Health Survey Repeat Re...
# 69     Rating cycle 2 - Total Health Inspection Score
# 70  Total Weighted Health Survey Score for two cyc...
# 71              Number of Facility-Reported Incidents
# 72                 Number of Substantiated Complaints
# 73                                    Number of Fines
# 74                   Total Amount of Fines in Dollars
# 75                          Number of Payment Denials
# 76                          Total Number of Penalties
# 77                               Location of facility
# 78                       Date the data were retrieved
#
#                                                Format
# 39                real number, up to 5 decimal places
# 40                real number, up to 5 decimal places
# 41                real number, up to 5 decimal places
# 42                real number, up to 5 decimal places
# 43                real number, up to 5 decimal places
# 44                real number, up to 5 decimal places
# 45                real number, up to 5 decimal places
# 46                real number, up to 5 decimal places
# 47                real number, up to 5 decimal places
# 48                                               date
# 49                                            integer
# 50                                               text
# 51                                               text
# 52                                               date
# 53                                            integer
# 54                                               date
# 55                                            integer
# 56                                            integer
# 57                                            integer
# 58                                            integer
# 59                                            integer
# 60                                            integer
# 61                                            integer
# 62                                               date
# 63                                            integer
# 64                                            integer
# 65                                            integer
# 66                                            integer
# 67                                            integer
# 68                                            integer
# 69                                            integer
# 70                real number, up to 3 decimal places
# 71                                            integer
# 72                                            integer
# 73                                            integer
# 74                                            integer
# 75                                            integer
# 76                                            integer
# 77  only on displayed version of file; renders as ...
# 78                                               date

# %%
data = pd.read_csv('./ml-data/providers-train.csv', encoding='latin1')

fine_counts = data.pop('FINE_CNT')
fine_totals = data.pop('FINE_TOT')
cycle_2_score = data.pop('CYCLE_2_TOTAL_SCORE')

# %%
data.head()
# Out:
#   PROVNUM                                     PROVNAME  \
# 0  015010                COOSA VALLEY NURSING FACILITY
# 1  015012                   HIGHLANDS HEALTH AND REHAB
# 2  015014  EASTVIEW REHABILITATION & HEALTHCARE CENTER
# 3  015015                PLANTATION MANOR NURSING HOME
# 4  015016         ATHENS HEALTH AND REHABILITATION LLC
#
#                                     ADDRESS        CITY STATE    ZIP  \
# 0                   315 WEST HICKORY STREET   SYLACAUGA    AL  35150
# 1                       380 WOODS COVE ROAD  SCOTTSBORO    AL  35768
# 2                  7755 FOURTH AVENUE SOUTH  BIRMINGHAM    AL  35206
# 3  6450 OLD TUSCALOOSA HIGHWAY   P O BOX 97    MC CALLA    AL  35111
# 4                    611 WEST MARKET STREET      ATHENS    AL  35611
#
#         PHONE  COUNTY_SSA COUNTY_NAME  BEDCERT  ...          CERTIFICATION  \
# 0  2562495604         600   Talladega       85  ...  Medicare and Medicaid
# 1  2562183708         350     Jackson       50  ...  Medicare and Medicaid
# 2  2058330146         360   Jefferson       92  ...  Medicare and Medicaid
# 3  2054776161         360   Jefferson      103  ...  Medicare and Medicaid
# 4  2562321620         410   Limestone      149  ...  Medicare and Medicaid
#
#    CYCLE_1_DEFS  CYCLE_1_NFROMDEFS  CYCLE_1_NFROMCOMP  CYCLE_1_DEFS_SCORE  \
# 0             7                  7                  0                  36
# 1             5                  5                  0                  44
# 2             6                  6                  0                  40
# 3             2                  2                  0                  16
# 4             2                  2                  0                  20
#
#    CYCLE_1_NUMREVIS  CYCLE_1_REVISIT_SCORE  CYCLE_1_TOTAL_SCORE  \
# 0                 1                      0                   36
# 1                 1                      0                   44
# 2                 1                      0                   40
# 3                 1                      0                   16
# 4                 1                      0                   20
#
#   CYCLE_1_SURVEY_DATE CYCLE_2_SURVEY_DATE
# 0          2017-04-06          2016-05-26
# 1          2017-03-16          2016-02-04
# 2          2016-10-20          2015-12-30
# 3          2017-03-09          2016-02-11
# 4          2017-06-01          2016-05-12
#
# [5 rows x 29 columns]

# %%
data.columns
# Out:
# Index(['PROVNUM', 'PROVNAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'PHONE',
#        'COUNTY_SSA', 'COUNTY_NAME', 'BEDCERT', 'RESTOT', 'INHOSP',
#        'CCRC_FACIL', 'SFF', 'CHOW_LAST_12MOS', 'SPRINKLER_STATUS', 'EXP_TOTAL',
#        'ADJ_TOTAL', 'OWNERSHIP', 'CERTIFICATION', 'CYCLE_1_DEFS',
#        'CYCLE_1_NFROMDEFS', 'CYCLE_1_NFROMCOMP', 'CYCLE_1_DEFS_SCORE',
#        'CYCLE_1_NUMREVIS', 'CYCLE_1_REVISIT_SCORE', 'CYCLE_1_TOTAL_SCORE',
#        'CYCLE_1_SURVEY_DATE', 'CYCLE_2_SURVEY_DATE'],
#       dtype='object')

# %%
data.groupby('STATE').agg({'PENALITY': np.mean})
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-15-35b6f5a2f6c2> in <module>
# ----> 1 data.groupby('STATE').agg({'PENALITY': np.mean})
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     352                 ) != len(keys):
#     353                     cols = sorted(set(keys) - set(obj.columns.intersection(keys)))
# --> 354                     raise SpecificationError(f"Column(s) {cols} do not exist")
#     355
#     356             from pandas.core.reshape.concat import concat
#
# SpecificationError: Column(s) ['PENALITY'] do not exist

# %% [markdown]
# ## Question 1: state_model
#
# A federal agency, Centers for Medicare and Medicaid Services (CMS), imposes regulations on nursing homes. However, nursing homes are inspected by state agencies for compliance with regulations, and fines for violations can vary widely between states.
#
# Let's develop a very simple initial model to predict the amount of fines a nursing home might expect to pay based on its location. Fill in the class definition of the custom estimator, `StateMeanEstimator`, below.
#
# **Note:** When the grader checks your answer, it passes a list of dictionaries to the `predict` method of your estimator, not a DataFrame. This means that your model must work with both data types. You can handle this by adding a test (and optional conversion) in the `predict` method of your custom class, similar to the `ColumnSelectTransformer` given below in Question 2.

# %%
from sklearn.base import BaseEstimator, RegressorMixin, TransformerMixin

class GroupMeanEstimator(BaseEstimator, RegressorMixin):
    def __init__(self, grouper):
        self.grouper = grouper
        self.group_averages = {}

    def fit(self, X, y):
        # Use self.group_averages to store the average penalty by group
        return self

    def predict(self, X):
        # Return a list of predicted penalties based on group of samples in X
        return [0] * len(X)

# %% [markdown]
# After filling in class definition, we can create an instance of the estimator and fit it to the data.

# %%
from sklearn.pipeline import Pipeline

state_model = Pipeline([
    ('sme', GroupMeanEstimator(grouper='STATE'))
    ])
state_model.fit(data, fine_totals)

# %% [markdown]
# Next we should test that our predict method works.

# %%
state_model.predict(data.sample(5))

# %% [markdown]
# However, what if we have data from a nursing home in a state (or territory) of the US which is not in the training data?

# %%
state_model.predict(pd.DataFrame([{'STATE': 'AS'}]))

# %% [markdown]
# Make sure your model can handle this possibility before submitting your model's predict method to the grader.

# %%
grader.score.ml__state_model(state_model.predict)

# %% [markdown]
# ## Question 2: simple_features_model
#
# Nursing homes vary greatly in their business characteristics. Some are owned by the government or non-profits while others are run for profit. Some house a few dozen residents while others house hundreds. Some are located within hospitals and may work with more vulnerable populations. We will try to predict which facilities are fined based on their business characteristics.
#
# We'll begin with columns in our DataFrame containing numeric and boolean features. Some of the rows contain null values; estimators cannot handle null values so these must be imputed or dropped. We will create a `Pipeline` containing transformers that process these features, followed by an estimator.
#
# **Note:** As mentioned above in Question 1, when the grader checks your answer, it passes a list of dictionaries to the `predict` or `predict_proba` method of your estimator, not a DataFrame. This means that your model must work with both data types. For this reason, we've provided a custom `ColumnSelectTransformer` for you to use instead `scikit-learn`'s own `ColumnTransformer`.

# %%
simple_cols = ['BEDCERT', 'RESTOT', 'INHOSP', 'CCRC_FACIL', 'SFF', 'CHOW_LAST_12MOS', 'SPRINKLER_STATUS', 'EXP_TOTAL', 'ADJ_TOTAL']

class ColumnSelectTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X)
        return X[self.columns]
        
simple_features = Pipeline([
    ('cst', ColumnSelectTransformer(simple_cols)),
])

# %% [markdown]
# **Note:** The assertion below assumes the output of `noncategorical_features.fit_transform` is a `ndarray`, not a `DataFrame`.)

# %%
assert data['RESTOT'].isnull().sum() > 0
assert not np.isnan(simple_features.fit_transform(data)).any()

# %% [markdown]
# Now combine the `simple_features` pipeline with an estimator in a new pipeline. Fit `simple_features_model` to the data and submit `simple_features_model.predict_proba` to the grader. You may wish to use cross-validation to tune the hyperparameters of your model.

# %%
simple_features_model = Pipeline([
    ('simple', simple_features),
    # add your estimator here
])

# %%
simple_features_model.fit(data, fine_counts > 0)

# %%
def positive_probability(model):
    def predict_proba(X):
        return model.predict_proba(X)[:, 1]
    return predict_proba

grader.score.ml__simple_features(positive_probability(simple_features_model))

# %% [markdown]
# ## Question 3: categorical_features

# %% [markdown]
# The `'OWNERSHIP'` and `'CERTIFICATION'` columns contain categorical data. We will have to encode the categorical data into numerical features before we pass them to an estimator. Construct one or more pipelines for this purpose. Transformers such as [LabelEncoder](https://scikit-learn.org/0.19/modules/generated/sklearn.preprocessing.LabelEncoder.html#sklearn.preprocessing.LabelEncoder) and [OneHotEncoder](https://scikit-learn.org/0.19/modules/generated/sklearn.preprocessing.OneHotEncoder.html#sklearn.preprocessing.OneHotEncoder) may be useful, but you may also want to define your own transformers.
#
# If you used more than one `Pipeline`, combine them with a `FeatureUnion`. As in Question 2, we will combine this with an estimator, fit it, and submit the `predict_proba` method to the grader.

# %%
from sklearn.pipeline import FeatureUnion

owner_onehot = Pipeline([
    ('cst', ColumnSelectTransformer(['OWNERSHIP'])),
])

cert_onehot = Pipeline([
    ('cst', ColumnSelectTransformer(['CERTIFICATION'])),
])

categorical_features = FeatureUnion([
])

# %%
assert categorical_features.fit_transform(data).shape[0] == data.shape[0]
assert categorical_features.fit_transform(data).dtype == np.float64
assert not np.isnan(categorical_features.fit_transform(data)).any()

# %% [markdown]
# As in the previous question, create a model using the `categorical_features`, fit it to the data, and submit its `predict_proba` method to the grader.

# %%
categorical_features_model = Pipeline([
    ('categorical', categorical_features),
    # add your estimator here
])

# %%
categorical_features_model.fit(data, fine_counts > 0)

# %%
grader.score.ml__categorical_features(positive_probability(categorical_features_model))

# %% [markdown]
# ## Question 4: business_model

# %% [markdown]
# Finally, we'll combine `simple_features` and `categorical_features` in a `FeatureUnion`, followed by an estimator in a `Pipeline`. You may want to optimize the hyperparameters of your estimator using cross-validation or try engineering new features (e.g. see [PolynomialFeatures](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html)). When you've assembled and trained your model, pass the `predict_proba` method to the grader.

# %%
business_features = FeatureUnion([
    ('simple', simple_features),
    ('categorical', categorical_features)
])

# %%
business_model = Pipeline([
    ('features', business_features),
    # add your estimator here
])

# %%
business_model.fit(data, fine_counts > 0)

# %%
grader.score.ml__business_model(positive_probability(business_model))

# %% [markdown]
# ## Question 5: survey_results

# %% [markdown]
# Surveys reveal safety and health deficiencies at nursing homes that may indicate risk for incidents (and penalties). CMS routinely makes surveys of nursing homes. Build a model that combines the `business_features` of each facility with its cycle 1 survey results, as well as the time between the cycle 1 and cycle 2 survey to predict the cycle 2 total score.
#
# First, let's create a transformer to calculate the difference in time between the cycle 1 and cycle 2 surveys.

# %%
class TimedeltaTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, t1_col, t2_col):
        self.t1_col = t1_col
        self.t2_col = t2_col

    def fit(self, X, y=None):
        return self

    def transform(self, X):

# %%
cycle_1_date = 'CYCLE_1_SURVEY_DATE'
cycle_2_date = 'CYCLE_2_SURVEY_DATE'
time_feature = TimedeltaTransformer(cycle_1_date, cycle_2_date)

# %% [markdown]
# In the cell below we'll collect the cycle 1 survey features.

# %%
cycle_1_cols = ['CYCLE_1_DEFS', 'CYCLE_1_NFROMDEFS', 'CYCLE_1_NFROMCOMP',
                'CYCLE_1_DEFS_SCORE', 'CYCLE_1_NUMREVIS',
                'CYCLE_1_REVISIT_SCORE', 'CYCLE_1_TOTAL_SCORE']
cycle_1_features = ...

# %%
from sklearn.ensemble import RandomForestRegressor

survey_model = Pipeline([
    ('features', FeatureUnion([
        ('business', business_features),
        ('survey', cycle_1_features),
        ('time', time_feature)
    ])),
    # add your estimator here
])

# %%
survey_model.fit(data, cycle_2_score.astype(int))

# %%
grader.score.ml__survey_model(survey_model.predict)

# %% [markdown]
# *Copyright &copy; 2021 WorldQuant University. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
